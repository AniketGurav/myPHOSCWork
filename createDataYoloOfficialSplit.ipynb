# %% [markdown]
# """
#     machine: laptop
#     this script creates yolo training data with IAM handwritten official split
#     Aim is to train yolov3 with this split and use the same split for training PHOSCNET
#
#     So the data is created in 2 ways from IAM official split.
#
#     1. Line level annotation is taken and only lines which belongs to training data are
#     considered. Here training data file contains train as well as test file.
#
#     Foloowing are the files created.
#     "mnist_train_PhoscIamOfficialSplitForYoloLineLevel1.txt"
#     "mnist_test_PhoscIamOfficialSplitForYoloLineLevel1.txt"
#
#
#     2.All Lines which are present on training data page are taken, So in this case few lines
#     can not be present in as IAM official split but will be considered for YOLOV# localization.
#
#
#
#
#
# """

# %%
import os
splitFilePath="./data/largeWriterIndependentTextLineRecognitionTask"

#os.listdir(splitFilePath)

trainFile=os.path.join(splitFilePath, 'trainset.txt')
testFile=os.path.join(splitFilePath,'testset.txt')
validFile1=os.path.join(splitFilePath,'validationset1.txt')
validFile2=os.path.join(splitFilePath,'validationset2.txt')

"""
    below function takes the line number and finds to which original image it 
    belongs, this image split will help to identify yolo train,test,valid data
    
"""
def gatherFormInOfficialSplitForYolo(temp):

    formsPath="/home/aniketag/Documents/phd/yolov5/data/datasets/forms//"

    gatherList=[]
    allLines=[]
    
    for indx,lineDetail in enumerate(temp):

        count=0
        imgNameIndx=0
        lineNoIndx=0
        #print(" lineDetail:",lineDetail)
        for charIndx,ele in enumerate(lineDetail):

            if ele=="-":
                count+=1
                
            if count==2:
                imgNameIndx=charIndx
                break
            if count==3:
                lineNoIndx=charIndx
                break

        pngName=lineDetail[:imgNameIndx]+".png"
        pngPath=os.path.join(formsPath,pngName)
        
        lineName=lineDetail#[:(imgNameIndx+2)]
        allLines.append(lineName)
        
        if os.path.isfile(pngPath):
            gatherList.append(pngName)

        #print(" check File:",os.path.isfile(pngPath))
    
    gatherList=list(set(gatherList))
    allLines=list(set(allLines))
    print(" total png gathered:",len(gatherList)," original lines:",len(temp),"unique lines:",len(allLines))    

    return gatherList,allLines

# %%
with open(trainFile) as f1:
    trainSet=f1.readlines()

trainList,trainLines=gatherFormInOfficialSplitForYolo(trainSet)

print(" train len:",len(trainList))
print(" trainLines len:",len(trainLines))


with open(testFile) as f1:
    testSet=f1.readlines()

testList,testLines=gatherFormInOfficialSplitForYolo(testSet)
    
with open(validFile1) as f1:
    validSet1=f1.readlines()

validList1,valLines1=gatherFormInOfficialSplitForYolo(validSet1)

with open(validFile2) as f1:
    validSet2=f1.readlines()

validList2,valLines2=gatherFormInOfficialSplitForYolo(validSet2)
    
validList=validList1+validList2
valLines=valLines1+valLines2


print(" test len:",len(testList))
print(" testLines len:",len(testLines))

print(" valid len:",len(validList))
print(" valLines len:",len(valLines))
# Out:
#  total png gathered: 747  original lines: 6161 unique lines: 6161
#  train len: 747
#  trainLines len: 6161
#  total png gathered: 232  original lines: 1861 unique lines: 1861
#  total png gathered: 105  original lines: 900 unique lines: 900
#  total png gathered: 115  original lines: 940 unique lines: 940
#  test len: 232
#  testLines len: 1861
#  valid len: 220
#  valLines len: 1840

# %%
"""
    checking - count to create a rule
"""

maxCount=0
counts=[]
for ele in trainSet:
    
    count=-1
    
    for char in ele:
        
        if char=="-":
            count+=1
        
        maxCount=max(count,maxCount)
        counts.append(count)
        
print("maxCount:",maxCount," min count:",min(counts))
# Out:
# maxCount: 1  min count: -1

# %% [markdown]
# """
#
#     The above list provides files in train,test,valid split
#
#     Next is to create Annotations for it
#
# """

# %%
len(trainSet),len(list(set(trainSet)))
#trainSet
# Out:
# (6161, 6161)

# %%
import pandas as pd
#df=pd.read_csv("./data/data3_phosc.csv")
df=pd.read_csv("./data/data_14_april.csv")
unqImages=set(df.image_name)
print("\n\t unique:",len(unqImages))
#print(data.columns)
# Out:
# 	 unique: 1539

# %%
df.head(100)
# Out:
#       image_name  class  width  height  org_x1  org_y1  org_x2  org_y2  \
# 0   g06-031n.png      1   2479    3542     435     678     450     697
# 1   g06-031n.png      1   2479    3542     425     683     663     777
# 2   g06-031n.png      1   2479    3542     640     726     696     779
# 3   g06-031n.png      1   2479    3542     727     685    1128     820
# 4   g06-031n.png      1   2479    3542    1129     692    1365     779
# ..           ...    ...    ...     ...     ...     ...     ...     ...
# 95  h07-054a.png      1    500     400    1097     853    1255     929
# 96  h07-054a.png      1    500     400    1313     845    1474     948
# 97  h07-054a.png      1    500     400    1512     843    1773     938
# 98  h07-054a.png      1    500     400    1797     838    2022     923
# 99  h07-054a.png      1    500     400     369    1036     509    1126
#
#          text        cropName     x     y     w     h
# 0           '  g06-031n-00-00  0.18  0.19  0.01  0.01
# 1        What  g06-031n-00-01  0.22  0.21  0.10  0.03
# 2           a  g06-031n-00-02  0.27  0.21  0.02  0.01
# 3   frightful  g06-031n-00-03  0.37  0.21  0.16  0.04
# 4       event  g06-031n-00-04  0.50  0.21  0.10  0.02
# ..        ...             ...   ...   ...   ...   ...
# 95      until  h07-054a-01-02  2.35  2.23  0.32  0.19
# 96      quite  h07-054a-01-03  2.79  2.24  0.32  0.26
# 97   recently  h07-054a-01-04  3.29  2.23  0.52  0.24
# 98      shown  h07-054a-01-05  3.82  2.20  0.45  0.21
# 99     little  h07-054a-02-00  0.88  2.70  0.28  0.23
#
# [100 rows x 14 columns]

# %%
len(trainList),len(validList),len(testList)
# Out:
# (747, 220, 232)

# %%
#for file in ['train','test']:
import numpy as np
import os

allImagesPath="/home/aniketag/Documents/phd/yolov5/data/datasets/forms//"
allImages=os.listdir(allImagesPath)
images_num=len(allImages)#len(os.listdir("/home/k/phd/yolov5/data/datasets/forms/"))
images_path = "./data/datasets/forms/" #allImagesPath # "/home/k/phd/yolov5/data/datasets/forms/"#os.getcwd()+f"/mnist_{file}"

#labels_txt = os.getcwd()+"/"+"mnist_train1.txt"

labels_txt =os.path.join(os.getcwd(),"mnist","mnist_train_PhoscIamOfficialSplitForYoloAllLineLevel1.txt")
labels_txt2 =os.path.join(os.getcwd(),"mnist","mnist_test_PhoscIamOfficialSplitForYoloAllLineLevel1.txt")

trainValCount,testCount=0,0

lastName=""
curLine=""
prevLine=""
unqImg=[]
exceptionCount=0

for indx,info in df.iterrows():
        
    imgName=info.image_name
    lineName=info.cropName[:-3]+"\n"
    
    
    try:
        if indx%100==0:
            print("\n\t unq images:",len(unqImg))

        if (imgName in trainList or imgName in validList):
            trainValCount+=1
            with open(labels_txt, "a") as wf:
                image_path =images_path+info["image_name"]

                if indx%100==0:
                    print("\n\t path:",image_path)

                if info["image_name"]!=lastName and info["image_name"] not in unqImg:
                    curLine=image_path

                    if len(prevLine):
                        #print("\n\t prevLine:",prevLine)
                        #wf.write( image_path+ "\n")
                        wf.write(prevLine+"\n")

                else:
                    xmin,ymin=str(int(info["org_x1"])),str(int(info["org_y1"]))
                    xmax,ymax=str(int(info["org_x2"])),str(int(info["org_y2"]))
                    curLine += ' ' + ','.join([xmin, ymin, xmax, ymax, str(0)])
                    prevLine=curLine

                lastName=info["image_name"]

        elif imgName in testList:
            testCount+=1
            with open(labels_txt2, "a") as wf:
                image_path =images_path+info["image_name"]

                if indx%100==0:
                    print("\n\t path:",image_path)

                if info["image_name"]!=lastName:
                    curLine=image_path

                    if len(prevLine):
                        #print("\n\t prevLine:",prevLine)
                        #wf.write( image_path+ "\n")
                        wf.write(prevLine+"\n")

                else:
                    xmin,ymin=str(int(info["org_x1"])),str(int(info["org_y1"]))
                    xmax,ymax=str(int(info["org_x2"])),str(int(info["org_y2"]))
                    curLine += ' ' + ','.join([xmin, ymin, xmax, ymax, str(0)])
                    prevLine=curLine

                lastName=info["image_name"]
            
        if info["image_name"] not in unqImg:
            unqImg.append(info["image_name"])

    except Exception as e:
        exceptionCount+=1
        print("\n\t exception index:",indx,"\t count:",exceptionCount)

        
print(" trainValCount:",trainValCount," testCount:",testCount)
# Out:
# 	 unq images: 0
#
# 	 unq images: 2
#
# 	 unq images: 3
#
# 	 path: ./data/datasets/forms/n06-119.png
#
# 	 unq images: 5
#
# 	 path: ./data/datasets/forms/e06-006.png
#
# 	 unq images: 6
#
# 	 path: ./data/datasets/forms/g06-018i.png
#
# 	 unq images: 7
#
# 	 path: ./data/datasets/forms/a03-009.png
#
# 	 unq images: 9
#
# 	 path: ./data/datasets/forms/g06-018f.png
#
# 	 unq images: 10
#
# 	 path: ./data/datasets/forms/g04-092.png
#
# 	 unq images: 11
#
# 	 path: ./data/datasets/forms/d06-086.png
#
# 	 unq images: 12
#
# 	 path: ./data/datasets/forms/c06-080.png
#
# 	 unq images: 13
#
# 	 path: ./data/datasets/forms/f04-087.png
#
# 	 unq images: 15
#
# 	 path: ./data/datasets/forms/d04-121.png
#
# 	 unq images: 16
#
# 	 path: ./data/datasets/forms/e07-079.png
#
# 	 unq images: 18
#
# 	 path: ./data/datasets/forms/c03-081c.png
#
# 	 unq images: 19
#
# 	 unq images: 20
#
# 	 path: ./data/datasets/forms/d06-063.png
#
# 	 unq images: 22
#
# 	 path: ./data/datasets/forms/a01-011u.png
#
# 	 unq images: 23
#
# 	 path: ./data/datasets/forms/g04-072.png
#
# 	 unq images: 24
#
# 	 unq images: 26
#
# 	 unq images: 27
#
# 	 path: ./data/datasets/forms/r02-089.png
#
# 	 unq images: 28
#
# 	 path: ./data/datasets/forms/a03-063.png
#
# 	 unq images: 29
#
# 	 path: ./data/datasets/forms/a01-096u.png
#
# 	 unq images: 30
#
# 	 path: ./data/datasets/forms/a06-100.png
#
# 	 unq images: 32
#
# 	 path: ./data/datasets/forms/e04-099.png
#
# 	 unq images: 33
#
# 	 path: ./data/datasets/forms/a01-087.png
#
# 	 unq images: 35
#
# 	 path: ./data/datasets/forms/f07-084b.png
#
# 	 unq images: 36
#
# 	 unq images: 37
#
# 	 path: ./data/datasets/forms/b01-053.png
#
# 	 unq images: 38
#
# 	 unq images: 39
#
# 	 path: ./data/datasets/forms/b01-057.png
#
# 	 unq images: 40
#
# 	 path: ./data/datasets/forms/r02-137.png
#
# 	 unq images: 42
#
# 	 unq images: 43
#
# 	 path: ./data/datasets/forms/d04-071.png
#
# 	 unq images: 45
#
# 	 path: ./data/datasets/forms/g06-011b.png
#
# 	 unq images: 46
#
# 	 path: ./data/datasets/forms/g06-045c.png
#
# 	 unq images: 47
#
# 	 path: ./data/datasets/forms/a04-059.png
#
# 	 unq images: 48
#
# 	 path: ./data/datasets/forms/a01-030u.png
#
# 	 unq images: 50
#
# 	 unq images: 51
#
# 	 path: ./data/datasets/forms/n02-049.png
#
# 	 unq images: 53
#
# 	 path: ./data/datasets/forms/g04-017.png
#
# 	 unq images: 54
#
# 	 path: ./data/datasets/forms/b06-075.png
#
# 	 unq images: 55
#
# 	 path: ./data/datasets/forms/m06-083.png
#
# 	 unq images: 56
#
# 	 path: ./data/datasets/forms/r02-060.png
#
# 	 unq images: 58
#
# 	 unq images: 59
#
# 	 path: ./data/datasets/forms/a06-070.png
#
# 	 unq images: 60
#
# 	 unq images: 61
#
# 	 path: ./data/datasets/forms/n06-194.png
#
# 	 unq images: 63
#
# 	 unq images: 64
#
# 	 path: ./data/datasets/forms/c03-021d.png
#
# 	 unq images: 65
#
# 	 path: ./data/datasets/forms/g01-008.png
#
# 	 unq images: 66
#
# 	 path: ./data/datasets/forms/r02-109.png
#
# 	 unq images: 68
#
# 	 unq images: 69
#
# 	 path: ./data/datasets/forms/a02-082.png
#
# 	 unq images: 71
#
# 	 path: ./data/datasets/forms/a02-024.png
#
# 	 unq images: 72
#
# 	 path: ./data/datasets/forms/a01-007u.png
#
# 	 unq images: 73
#
# 	 path: ./data/datasets/forms/a01-113u.png
#
# 	 unq images: 75
#
# 	 unq images: 77
#
# 	 path: ./data/datasets/forms/n01-000.png
#
# 	 unq images: 78
#
# 	 path: ./data/datasets/forms/g06-031h.png
#
# 	 unq images: 79
#
# 	 path: ./data/datasets/forms/a05-039.png
#
# 	 unq images: 81
#
# 	 path: ./data/datasets/forms/c04-039.png
#
# 	 unq images: 82
#
# 	 unq images: 83
#
# 	 path: ./data/datasets/forms/g06-037h.png
#
# 	 unq images: 84
#
# 	 unq images: 85
#
# 	 path: ./data/datasets/forms/p02-076.png
#
# 	 unq images: 87
#
# 	 path: ./data/datasets/forms/f02-033.png
#
# 	 unq images: 88
#
# 	 path: ./data/datasets/forms/m02-102.png
#
# 	 unq images: 89
#
# 	 path: ./data/datasets/forms/a01-128u.png
#
# 	 unq images: 90
#
# 	 path: ./data/datasets/forms/r03-026.png
#
# 	 unq images: 91
#
# 	 unq images: 92
#
# 	 path: ./data/datasets/forms/g05-094.png
#
# 	 unq images: 94
#
# 	 path: ./data/datasets/forms/a02-027.png
#
# 	 unq images: 95
#
# 	 path: ./data/datasets/forms/f07-032a.png
#
# 	 unq images: 96
#
# 	 path: ./data/datasets/forms/f03-174.png
#
# 	 unq images: 97
#
# 	 path: ./data/datasets/forms/a06-039.png
#
# 	 unq images: 99
#
# 	 path: ./data/datasets/forms/p03-142.png
#
# 	 unq images: 100
#
# 	 unq images: 101
#
# 	 path: ./data/datasets/forms/a03-037.png
#
# 	 unq images: 102
#
# 	 path: ./data/datasets/forms/g06-037l.png
#
# 	 unq images: 104
#
# 	 unq images: 105
#
# 	 path: ./data/datasets/forms/c03-084b.png
#
# 	 unq images: 107
#
# 	 path: ./data/datasets/forms/r02-038.png
#
# 	 unq images: 108
#
# 	 path: ./data/datasets/forms/n04-209.png
#
# 	 unq images: 110
#
# 	 path: ./data/datasets/forms/a03-089.png
#
# 	 unq images: 112
#
# 	 path: ./data/datasets/forms/p06-052.png
#
# 	 unq images: 113
#
# 	 path: ./data/datasets/forms/c04-056.png
#
# 	 unq images: 115
#
# 	 path: ./data/datasets/forms/c04-116.png
#
# 	 unq images: 116
#
# 	 unq images: 117
#
# 	 unq images: 118
#
# 	 path: ./data/datasets/forms/e07-076.png
#
# 	 unq images: 120
#
# 	 unq images: 121
#
# 	 path: ./data/datasets/forms/a01-113.png
#
# 	 unq images: 122
#
# 	 path: ./data/datasets/forms/d06-025.png
#
# 	 unq images: 124
#
# 	 unq images: 125
#
# 	 path: ./data/datasets/forms/b01-132.png
#
# 	 unq images: 126
#
# 	 path: ./data/datasets/forms/a02-098.png
#
# 	 unq images: 127
#
# 	 path: ./data/datasets/forms/n06-092.png
#
# 	 unq images: 129
#
# 	 path: ./data/datasets/forms/r02-146.png
#
# 	 unq images: 130
#
# 	 path: ./data/datasets/forms/b01-062.png
#
# 	 unq images: 132
#
# 	 unq images: 132
#
# 	 unq images: 133
#
# 	 path: ./data/datasets/forms/f03-182.png
#
# 	 unq images: 135
#
# 	 path: ./data/datasets/forms/f01-135.png
#
# 	 unq images: 137
#
# 	 unq images: 138
#
# 	 unq images: 139
#
# 	 path: ./data/datasets/forms/n04-052.png
#
# 	 unq images: 140
#
# 	 path: ./data/datasets/forms/g06-011k.png
#
# 	 unq images: 141
#
# 	 path: ./data/datasets/forms/b04-140.png
#
# 	 unq images: 142
#
# 	 path: ./data/datasets/forms/d06-056.png
#
# 	 unq images: 144
#
# 	 path: ./data/datasets/forms/b04-047.png
#
# 	 unq images: 145
#
# 	 path: ./data/datasets/forms/b04-154.png
#
# 	 unq images: 147
#
# 	 path: ./data/datasets/forms/n04-156.png
#
# 	 unq images: 148
#
# 	 unq images: 149
#
# 	 path: ./data/datasets/forms/n02-045.png
#
# 	 unq images: 151
#
# 	 unq images: 152
#
# 	 unq images: 153
#
# 	 unq images: 154
#
# 	 path: ./data/datasets/forms/n04-000.png
#
# 	 unq images: 156
#
# 	 path: ./data/datasets/forms/g04-108.png
#
# 	 unq images: 158
#
# 	 path: ./data/datasets/forms/c03-007c.png
#
# 	 unq images: 159
#
# 	 path: ./data/datasets/forms/c06-058.png
#
# 	 unq images: 161
#
# 	 path: ./data/datasets/forms/a05-094.png
#
# 	 unq images: 162
#
# 	 path: ./data/datasets/forms/c06-020.png
#
# 	 unq images: 163
#
# 	 unq images: 165
#
# 	 path: ./data/datasets/forms/n02-000.png
#
# 	 unq images: 166
#
# 	 path: ./data/datasets/forms/e01-086.png
#
# 	 unq images: 167
#
# 	 path: ./data/datasets/forms/b02-097.png
#
# 	 unq images: 169
#
# 	 path: ./data/datasets/forms/n04-213.png
#
# 	 unq images: 170
#
# 	 path: ./data/datasets/forms/d06-015.png
#
# 	 unq images: 172
#
# 	 path: ./data/datasets/forms/c03-007f.png
#
# 	 unq images: 173
#
# 	 path: ./data/datasets/forms/e07-098.png
#
# 	 unq images: 174
#
# 	 path: ./data/datasets/forms/m01-131.png
#
# 	 unq images: 176
#
# 	 path: ./data/datasets/forms/g03-064.png
#
# 	 unq images: 178
#
# 	 path: ./data/datasets/forms/g03-004.png
#
# 	 unq images: 179
#
# 	 path: ./data/datasets/forms/b06-027.png
#
# 	 unq images: 181
#
# 	 path: ./data/datasets/forms/b06-090.png
#
# 	 unq images: 182
#
# 	 unq images: 184
#
# 	 path: ./data/datasets/forms/n02-154.png
#
# 	 unq images: 185
#
# 	 path: ./data/datasets/forms/a01-122u.png
#
# 	 unq images: 186
#
# 	 unq images: 187
#
# 	 path: ./data/datasets/forms/c03-081a.png
#
# 	 unq images: 189
#
# 	 path: ./data/datasets/forms/b06-068.png
#
# 	 unq images: 190
#
# 	 path: ./data/datasets/forms/b06-087.png
#
# 	 unq images: 192
#
# 	 path: ./data/datasets/forms/a02-032.png
#
# 	 unq images: 193
#
# 	 path: ./data/datasets/forms/e02-094.png
#
# 	 unq images: 194
#
# 	 unq images: 196
#
# 	 unq images: 197
#
# 	 path: ./data/datasets/forms/n02-157.png
#
# 	 unq images: 198
#
# 	 path: ./data/datasets/forms/a04-043.png
#
# 	 unq images: 200
#
# 	 path: ./data/datasets/forms/g06-050k.png
#
# 	 unq images: 201
#
# 	 unq images: 202
#
# 	 path: ./data/datasets/forms/f04-053.png
#
# 	 unq images: 204
#
# 	 unq images: 205
#
# 	 path: ./data/datasets/forms/b03-114.png
#
# 	 unq images: 207
#
# 	 path: ./data/datasets/forms/d07-100.png
#
# 	 unq images: 208
#
# 	 path: ./data/datasets/forms/g01-067.png
#
# 	 unq images: 209
#
# 	 path: ./data/datasets/forms/e04-030.png
#
# 	 unq images: 211
#
# 	 path: ./data/datasets/forms/a01-102u.png
#
# 	 unq images: 212
#
# 	 path: ./data/datasets/forms/p02-008.png
#
# 	 unq images: 214
#
# 	 unq images: 215
#
# 	 path: ./data/datasets/forms/f04-064.png
#
# 	 unq images: 216
#
# 	 path: ./data/datasets/forms/r02-065.png
#
# 	 unq images: 218
#
# 	 path: ./data/datasets/forms/n02-104.png
#
# 	 unq images: 219
#
# 	 path: ./data/datasets/forms/c02-035.png
#
# 	 unq images: 221
#
# 	 path: ./data/datasets/forms/n06-111.png
#
# 	 unq images: 222
#
# 	 path: ./data/datasets/forms/f04-079.png
#
# 	 unq images: 223
#
# 	 path: ./data/datasets/forms/c06-043.png
#
# 	 unq images: 224
#
# 	 path: ./data/datasets/forms/a03-030.png
#
# 	 unq images: 226
#
# 	 unq images: 227
#
# 	 path: ./data/datasets/forms/n06-140.png
#
# 	 unq images: 228
#
# 	 path: ./data/datasets/forms/n06-100.png
#
# 	 unq images: 230
#
# 	 unq images: 231
#
# 	 path: ./data/datasets/forms/g06-042i.png
#
# 	 unq images: 233
#
# 	 path: ./data/datasets/forms/h01-004.png
#
# 	 unq images: 234
#
# 	 unq images: 236
#
# 	 path: ./data/datasets/forms/d04-005.png
# 	 unq images: 237
#
# 	 path: ./data/datasets/forms/n04-218.png
#
# 	 unq images: 238
#
# 	 path: ./data/datasets/forms/e06-030.png
#
# 	 unq images: 239
#
# 	 unq images: 241
#
# 	 path: ./data/datasets/forms/p06-047.png
#
# 	 unq images: 242
#
# 	 path: ./data/datasets/forms/g01-037.png
#
# 	 unq images: 243
#
# 	 path: ./data/datasets/forms/g06-037g.png
#
# 	 unq images: 245
#
# 	 path: ./data/datasets/forms/f04-093.png
#
# 	 unq images: 246
#
# 	 path: ./data/datasets/forms/f07-081b.png
#
# 	 unq images: 247
#
# 	 path: ./data/datasets/forms/a01-003.png
#
# 	 unq images: 249
#
# 	 path: ./data/datasets/forms/g06-018m.png
#
# 	 unq images: 250
#
# 	 path: ./data/datasets/forms/f07-039a.png
#
# 	 unq images: 252
#
# 	 path: ./data/datasets/forms/d04-066.png
#
# 	 unq images: 253
#
# 	 unq images: 254
#
# 	 unq images: 255
#
# 	 path: ./data/datasets/forms/f01-075.png
#
# 	 unq images: 257
#
# 	 path: ./data/datasets/forms/e04-062.png
#
# 	 unq images: 258
#
# 	 path: ./data/datasets/forms/g07-000b.png
#
# 	 unq images: 259
#
# 	 path: ./data/datasets/forms/e07-105.png
#
# 	 unq images: 261
#
# 	 path: ./data/datasets/forms/f07-088a.png
#
# 	 unq images: 262
#
# 	 path: ./data/datasets/forms/g03-032.png
#
# 	 unq images: 264
#
# 	 path: ./data/datasets/forms/d01-080.png
#
# 	 unq images: 265
#
# 	 path: ./data/datasets/forms/f07-006.png
#
# 	 unq images: 267
#
# 	 path: ./data/datasets/forms/a03-023.png
#
# 	 unq images: 268
#
# 	 path: ./data/datasets/forms/g06-026k.png
#
# 	 unq images: 269
#
# 	 path: ./data/datasets/forms/m04-164.png
#
# 	 unq images: 270
#
# 	 path: ./data/datasets/forms/g06-031m.png
#
# 	 unq images: 272
#
# 	 path: ./data/datasets/forms/m04-131.png
#
# 	 unq images: 273
#
# 	 path: ./data/datasets/forms/p03-112.png
#
# 	 unq images: 274
#
# 	 path: ./data/datasets/forms/n06-186.png
#
# 	 unq images: 275
#
# 	 path: ./data/datasets/forms/b04-040.png
#
# 	 unq images: 277
#
# 	 path: ./data/datasets/forms/n06-163.png
#
# 	 unq images: 278
#
# 	 unq images: 279
#
# 	 unq images: 280
#
# 	 unq images: 281
#
# 	 path: ./data/datasets/forms/p03-185.png
#
# 	 unq images: 282
#
# 	 path: ./data/datasets/forms/a02-053.png
#
# 	 unq images: 284
#
# 	 path: ./data/datasets/forms/e07-012.png
#
# 	 unq images: 285
#
# 	 path: ./data/datasets/forms/c03-084f.png
#
# 	 unq images: 286
#
# 	 path: ./data/datasets/forms/p03-173.png
#
# 	 unq images: 287
#
# 	 path: ./data/datasets/forms/d04-131.png
#
# 	 unq images: 289
#
# 	 unq images: 290
#
# 	 path: ./data/datasets/forms/f01-085.png
#
# 	 unq images: 292
#
# 	 unq images: 293
#
# 	 unq images: 295
#
# 	 path: ./data/datasets/forms/a03-047.png
#
# 	 unq images: 296
#
# 	 path: ./data/datasets/forms/e06-000.png
#
# 	 unq images: 297
#
# 	 path: ./data/datasets/forms/b05-042.png
#
# 	 unq images: 298
#
# 	 path: ./data/datasets/forms/g06-037c.png
#
# 	 unq images: 299
#
# 	 path: ./data/datasets/forms/g02-062.png
#
# 	 unq images: 301
#
# 	 path: ./data/datasets/forms/d06-000.png
#
# 	 unq images: 302
#
# 	 unq images: 303
#
# 	 unq images: 304
#
# 	 path: ./data/datasets/forms/r03-056.png
#
# 	 unq images: 306
#
# 	 path: ./data/datasets/forms/f04-024.png
#
# 	 unq images: 307
#
# 	 path: ./data/datasets/forms/g06-026c.png
#
# 	 unq images: 309
#
# 	 path: ./data/datasets/forms/p02-105.png
#
# 	 unq images: 310
#
# 	 path: ./data/datasets/forms/b06-032.png
#
# 	 unq images: 311
#
# 	 path: ./data/datasets/forms/e01-018.png
#
# 	 unq images: 313
#
# 	 path: ./data/datasets/forms/p03-121.png
#
# 	 unq images: 314
#
# 	 path: ./data/datasets/forms/m06-056.png
#
# 	 unq images: 316
#
# 	 path: ./data/datasets/forms/c03-007.png
#
# 	 unq images: 317
#
# 	 unq images: 318
#
# 	 unq images: 320
#
# 	 path: ./data/datasets/forms/c03-087d.png
#
# 	 unq images: 321
#
# 	 path: ./data/datasets/forms/e02-117.png
#
# 	 unq images: 322
#
# 	 path: ./data/datasets/forms/f07-024b.png
#
# 	 unq images: 324
#
# 	 path: ./data/datasets/forms/m04-100.png
#
# 	 unq images: 325
#
# 	 path: ./data/datasets/forms/h04-000.png
#
# 	 unq images: 326
#
# 	 path: ./data/datasets/forms/r06-049.png
#
# 	 unq images: 328
#
# 	 path: ./data/datasets/forms/m01-090.png
#
# 	 unq images: 329
#
# 	 path: ./data/datasets/forms/r02-054.png
#
# 	 unq images: 330
#
# 	 unq images: 331
#
# 	 path: ./data/datasets/forms/p03-027.png
#
# 	 unq images: 333
#
# 	 path: ./data/datasets/forms/n02-009.png
#
# 	 unq images: 334
#
# 	 unq images: 335
#
# 	 path: ./data/datasets/forms/a06-051.png
#
# 	 unq images: 337
#
# 	 unq images: 338
#
# 	 unq images: 339
#
# 	 unq images: 341
#
# 	 path: ./data/datasets/forms/m04-019.png
#
# 	 unq images: 342
#
# 	 path: ./data/datasets/forms/r06-044.png
#
# 	 unq images: 343
#
# 	 path: ./data/datasets/forms/f07-076a.png
#
# 	 unq images: 345
#
# 	 unq images: 346
#
# 	 path: ./data/datasets/forms/g06-045f.png
#
# 	 unq images: 348
#
# 	 path: ./data/datasets/forms/n06-182.png
#
# 	 unq images: 349
#
# 	 path: ./data/datasets/forms/m02-095.png
#
# 	 unq images: 351
#
# 	 path: ./data/datasets/forms/a01-053u.png
#
# 	 unq images: 352
#
# 	 unq images: 354
#
# 	 path: ./data/datasets/forms/n02-114.png
#
# 	 unq images: 355
#
# 	 path: ./data/datasets/forms/a06-157.png
#
# 	 unq images: 357
#
# 	 path: ./data/datasets/forms/r06-111.png
#
# 	 unq images: 358
#
# 	 path: ./data/datasets/forms/g01-088.png
#
# 	 unq images: 359
#
# 	 path: ./data/datasets/forms/e01-055.png
#
# 	 unq images: 360
#
# 	 path: ./data/datasets/forms/m02-052.png
#
# 	 unq images: 362
#
# 	 path: ./data/datasets/forms/g01-000.png
#
# 	 unq images: 363
#
# 	 path: ./data/datasets/forms/g03-043.png
#
# 	 unq images: 365
#
# 	 path: ./data/datasets/forms/c04-050.png
#
# 	 unq images: 366
#
# 	 unq images: 368
#
# 	 path: ./data/datasets/forms/m04-030.png
#
# 	 unq images: 369
#
# 	 unq images: 370
#
# 	 path: ./data/datasets/forms/a03-027.png
#
# 	 unq images: 371
#
# 	 unq images: 372
#
# 	 path: ./data/datasets/forms/a01-038.png
#
# 	 unq images: 374
#
# 	 path: ./data/datasets/forms/n06-148.png
#
# 	 unq images: 375
#
# 	 path: ./data/datasets/forms/d01-104.png
#
# 	 unq images: 376
#
# 	 path: ./data/datasets/forms/e04-008.png
#
# 	 unq images: 378
#
# 	 path: ./data/datasets/forms/m06-091.png
#
# 	 unq images: 379
#
# 	 unq images: 380
#
# 	 path: ./data/datasets/forms/p02-101.png
#
# 	 unq images: 382
#
# 	 path: ./data/datasets/forms/f01-081.png
#
# 	 unq images: 383
#
# 	 path: ./data/datasets/forms/f04-016.png
#
# 	 unq images: 385
#
# 	 path: ./data/datasets/forms/g01-083.png
#
# 	 unq images: 386
#
# 	 path: ./data/datasets/forms/c03-096b.png
#
# 	 unq images: 387
#
# 	 path: ./data/datasets/forms/n02-037.png
#
# 	 unq images: 389
#
# 	 path: ./data/datasets/forms/b01-136.png
#
# 	 unq images: 390
#
# 	 path: ./data/datasets/forms/a06-119.png
#
# 	 unq images: 391
#
# 	 path: ./data/datasets/forms/d04-012.png
#
# 	 unq images: 393
#
# 	 path: ./data/datasets/forms/e06-015.png
#
# 	 unq images: 394
#
# 	 path: ./data/datasets/forms/g06-031j.png
#
# 	 unq images: 395
#
# 	 path: ./data/datasets/forms/c04-075.png
#
# 	 unq images: 396
#
# 	 path: ./data/datasets/forms/b04-147.png
#
# 	 unq images: 398
#
# 	 path: ./data/datasets/forms/b06-097.png
#
# 	 unq images: 399
#
# 	 path: ./data/datasets/forms/p02-109.png
#
# 	 unq images: 400
#
# 	 path: ./data/datasets/forms/n04-009.png
#
# 	 unq images: 401
#
# 	 path: ./data/datasets/forms/m02-069.png
#
# 	 unq images: 403
#
# 	 path: ./data/datasets/forms/a06-147.png
#
# 	 unq images: 404
#
# 	 unq images: 405
#
# 	 unq images: 407
#
# 	 path: ./data/datasets/forms/c03-094f.png
#
# 	 unq images: 408
#
# 	 unq images: 409
#
# 	 path: ./data/datasets/forms/g06-037k.png
#
# 	 unq images: 410
#
# 	 path: ./data/datasets/forms/a06-124.png
#
# 	 unq images: 412
#
# 	 path: ./data/datasets/forms/a03-066.png
#
# 	 unq images: 414
#
# 	 unq images: 415
#
# 	 path: ./data/datasets/forms/f03-191.png
#
# 	 unq images: 417
#
# 	 path: ./data/datasets/forms/a02-008.png
#
# 	 unq images: 418
#
# 	 path: ./data/datasets/forms/d06-050.png
#
# 	 unq images: 419
#
# 	 unq images: 421
#
# 	 path: ./data/datasets/forms/e01-107.png
#
# 	 unq images: 422
#
# 	 unq images: 423
#
# 	 path: ./data/datasets/forms/n06-128.png
#
# 	 unq images: 424
#
# 	 path: ./data/datasets/forms/a01-122.png
#
# 	 unq images: 425
#
# 	 path: ./data/datasets/forms/k04-022.png
#
# 	 unq images: 427
#
# 	 path: ./data/datasets/forms/n04-183.png
#
# 	 unq images: 428
#
# 	 path: ./data/datasets/forms/m02-075.png
#
# 	 unq images: 430
#
# 	 path: ./data/datasets/forms/e07-090.png
#
# 	 unq images: 431
#
# 	 path: ./data/datasets/forms/g06-047d.png
#
# 	 unq images: 432
#
# 	 path: ./data/datasets/forms/f04-049.png
#
# 	 unq images: 434
#
# 	 path: ./data/datasets/forms/p02-135.png
#
# 	 unq images: 435
#
# 	 path: ./data/datasets/forms/b01-113.png
#
# 	 unq images: 437
#
# 	 path: ./data/datasets/forms/r06-041.png
#
# 	 unq images: 438
#
# 	 unq images: 439
#
# 	 path: ./data/datasets/forms/b04-121.png
#
# 	 unq images: 441
#
# 	 path: ./data/datasets/forms/n04-139.png
#
# 	 unq images: 442
#
# 	 path: ./data/datasets/forms/c03-021e.png
#
# 	 unq images: 443
#
# 	 path: ./data/datasets/forms/b01-094.png
#
# 	 unq images: 445
#
# 	 path: ./data/datasets/forms/b05-088.png
#
# 	 unq images: 446
#
# 	 path: ./data/datasets/forms/p02-069.png
#
# 	 unq images: 447
#
# 	 path: ./data/datasets/forms/g04-088.png
#
# 	 unq images: 448
#
# 	 path: ./data/datasets/forms/g06-037f.png
#
# 	 unq images: 449
#
# 	 path: ./data/datasets/forms/f02-076.png
#
# 	 unq images: 451
#
# 	 path: ./data/datasets/forms/c03-087e.png
#
# 	 unq images: 452
#
# 	 path: ./data/datasets/forms/g06-031e.png
#
# 	 unq images: 453
#
# 	 path: ./data/datasets/forms/a04-019.png
#
# 	 unq images: 455
#
# 	 path: ./data/datasets/forms/r06-011.png
#
# 	 unq images: 456
#
# 	 path: ./data/datasets/forms/g06-042c.png
#
# 	 unq images: 458
#
# 	 path: ./data/datasets/forms/f01-058.png
#
# 	 unq images: 459
#
# 	 path: ./data/datasets/forms/m06-042.png
#
# 	 unq images: 461
#
# 	 path: ./data/datasets/forms/a01-049x.png
#
# 	 unq images: 462
#
# 	 path: ./data/datasets/forms/a06-044.png
#
# 	 unq images: 463
#
# 	 path: ./data/datasets/forms/c06-039.png
# 	 unq images: 464
#
# 	 unq images: 466
#
# 	 path: ./data/datasets/forms/m02-112.png
#
# 	 unq images: 468
#
# 	 path: ./data/datasets/forms/b04-162.png
#
# 	 unq images: 469
#
# 	 path: ./data/datasets/forms/g06-031g.png
#
# 	 unq images: 470
#
# 	 path: ./data/datasets/forms/g04-048.png
#
# 	 unq images: 472
#
# 	 unq images: 473
#
# 	 unq images: 474
#
# 	 unq images: 476
#
# 	 path: ./data/datasets/forms/g06-031l.png
#
# 	 unq images: 477
#
# 	 path: ./data/datasets/forms/d06-041.png
#
# 	 unq images: 478
#
# 	 unq images: 480
#
# 	 path: ./data/datasets/forms/e04-079.png
#
# 	 unq images: 481
#
# 	 path: ./data/datasets/forms/m06-048.png
#
# 	 unq images: 483
#
# 	 unq images: 484
#
# 	 path: ./data/datasets/forms/c06-103.png
#
# 	 unq images: 486
#
# 	 unq images: 487
#
# 	 path: ./data/datasets/forms/a01-063x.png
#
# 	 unq images: 488
#
# 	 path: ./data/datasets/forms/c03-081e.png
#
# 	 unq images: 489
#
# 	 path: ./data/datasets/forms/g06-050l.png
#
# 	 unq images: 491
#
# 	 unq images: 492
#
# 	 path: ./data/datasets/forms/f01-070.png
#
# 	 unq images: 494
#
# 	 unq images: 495
#
# 	 path: ./data/datasets/forms/b01-122.png
#
# 	 unq images: 496
#
# 	 path: ./data/datasets/forms/c03-016e.png
#
# 	 unq images: 498
#
# 	 unq images: 499
#
# 	 path: ./data/datasets/forms/c03-003f.png
#
# 	 unq images: 500
#
# 	 path: ./data/datasets/forms/f01-053.png
#
# 	 unq images: 501
#
# 	 unq images: 503
#
# 	 unq images: 504
#
# 	 unq images: 505
#
# 	 path: ./data/datasets/forms/g01-039.png
#
# 	 unq images: 507
#
# 	 path: ./data/datasets/forms/g06-011m.png
#
# 	 unq images: 508
#
# 	 path: ./data/datasets/forms/b02-013.png
#
# 	 unq images: 509
#
# 	 path: ./data/datasets/forms/c03-021f.png
#
# 	 unq images: 510
#
# 	 path: ./data/datasets/forms/a03-034.png
#
# 	 unq images: 512
#
# 	 path: ./data/datasets/forms/b04-103.png
#
# 	 unq images: 513
#
# 	 path: ./data/datasets/forms/r06-062.png
#
# 	 unq images: 515
#
# 	 path: ./data/datasets/forms/n04-015.png
#
# 	 unq images: 516
#
# 	 path: ./data/datasets/forms/d05-008.png
#
# 	 unq images: 517
#
# 	 path: ./data/datasets/forms/c03-084c.png
#
# 	 unq images: 519
#
# 	 unq images: 520
#
# 	 path: ./data/datasets/forms/e04-114.png
#
# 	 unq images: 521
#
# 	 path: ./data/datasets/forms/g03-052.png
#
# 	 unq images: 522
#
# 	 path: ./data/datasets/forms/e02-086.png
#
# 	 unq images: 523
#
# 	 path: ./data/datasets/forms/b04-004.png
#
# 	 unq images: 525
#
# 	 path: ./data/datasets/forms/g04-022.png
#
# 	 unq images: 526
#
# 	 path: ./data/datasets/forms/g06-011e.png
#
# 	 unq images: 527
#
# 	 path: ./data/datasets/forms/n06-123.png
#
# 	 unq images: 528
#
# 	 unq images: 529
#
# 	 path: ./data/datasets/forms/g05-098.png
#
# 	 unq images: 530
#
# 	 path: ./data/datasets/forms/g06-047m.png
#
# 	 unq images: 532
#
# 	 path: ./data/datasets/forms/a01-030.png
#
# 	 unq images: 533
#
# 	 path: ./data/datasets/forms/a03-080.png
#
# 	 unq images: 535
#
# 	 path: ./data/datasets/forms/c03-000d.png
#
# 	 unq images: 536
#
# 	 unq images: 537
#
# 	 path: ./data/datasets/forms/m01-060.png
#
# 	 unq images: 539
#
# 	 path: ./data/datasets/forms/m04-000.png
#
# 	 unq images: 540
#
# 	 path: ./data/datasets/forms/e04-109.png
#
# 	 unq images: 542
#
# 	 path: ./data/datasets/forms/g01-034.png
#
# 	 unq images: 543
#
# 	 path: ./data/datasets/forms/a04-096.png
#
# 	 unq images: 544
#
# 	 path: ./data/datasets/forms/n06-175.png
#
# 	 unq images: 546
#
# 	 path: ./data/datasets/forms/d06-072.png
#
# 	 unq images: 547
#
# 	 unq images: 548
#
# 	 path: ./data/datasets/forms/b01-009.png
#
# 	 unq images: 550
#
# 	 path: ./data/datasets/forms/p03-080.png
#
# 	 unq images: 551
#
# 	 unq images: 553
#
# 	 path: ./data/datasets/forms/a05-108.png
#
# 	 unq images: 554
#
# 	 path: ./data/datasets/forms/c06-128.png
#
# 	 unq images: 556
#
# 	 path: ./data/datasets/forms/g06-042b.png
#
# 	 unq images: 557
#
# 	 path: ./data/datasets/forms/a05-022.png
#
# 	 unq images: 559
#
# 	 path: ./data/datasets/forms/c01-009.png
#
# 	 unq images: 560
#
# 	 unq images: 561
#
# 	 path: ./data/datasets/forms/c03-094b.png
#
# 	 unq images: 563
#
# 	 path: ./data/datasets/forms/f02-036.png
#
# 	 unq images: 564
#
# 	 path: ./data/datasets/forms/a01-068u.png
#
# 	 unq images: 566
#
# 	 path: ./data/datasets/forms/c02-089.png
#
# 	 unq images: 567
#
# 	 path: ./data/datasets/forms/e04-068.png
#
# 	 unq images: 569
#
# 	 path: ./data/datasets/forms/c04-165.png
#
# 	 unq images: 570
#
# 	 path: ./data/datasets/forms/m02-106.png
#
# 	 unq images: 572
#
# 	 unq images: 573
#
# 	 path: ./data/datasets/forms/a02-037.png
#
# 	 unq images: 574
#
# 	 path: ./data/datasets/forms/m03-062.png
#
# 	 unq images: 575
#
# 	 path: ./data/datasets/forms/m04-043.png
#
# 	 unq images: 576
#
# 	 unq images: 578
#
# 	 path: ./data/datasets/forms/a01-058u.png
#
# 	 unq images: 579
#
# 	 path: ./data/datasets/forms/b06-004.png
#
# 	 unq images: 581
#
# 	 unq images: 582
#
# 	 unq images: 583
#
# 	 path: ./data/datasets/forms/e01-092.png
#
# 	 unq images: 585
#
# 	 path: ./data/datasets/forms/e04-004.png
#
# 	 unq images: 586
#
# 	 path: ./data/datasets/forms/a01-030x.png
#
# 	 unq images: 587
#
# 	 path: ./data/datasets/forms/a06-114.png
#
# 	 unq images: 589
#
# 	 path: ./data/datasets/forms/p06-248.png
#
# 	 unq images: 590
#
# 	 path: ./data/datasets/forms/b04-181.png
#
# 	 unq images: 592
#
# 	 path: ./data/datasets/forms/b01-033.png
#
# 	 unq images: 594
#
# 	 unq images: 595
#
# 	 unq images: 596
#
# 	 path: ./data/datasets/forms/c04-098.png
#
# 	 unq images: 598
#
# 	 unq images: 599
#
# 	 unq images: 601
#
# 	 path: ./data/datasets/forms/k04-017.png
#
# 	 unq images: 602
#
# 	 path: ./data/datasets/forms/f07-002.png
#
# 	 unq images: 603
#
# 	 path: ./data/datasets/forms/c03-087a.png
#
# 	 unq images: 605
#
# 	 path: ./data/datasets/forms/g06-011c.png
#
# 	 unq images: 606
#
# 	 path: ./data/datasets/forms/g05-087.png
#
# 	 unq images: 607
#
# 	 unq images: 609
#
# 	 path: ./data/datasets/forms/g06-018b.png
#
# 	 unq images: 610
#
# 	 unq images: 611
#
# 	 path: ./data/datasets/forms/b04-134.png
#
# 	 unq images: 613
#
# 	 unq images: 614
#
# 	 path: ./data/datasets/forms/e07-083.png
#
# 	 unq images: 615
#
# 	 path: ./data/datasets/forms/a01-132u.png
#
# 	 unq images: 617
#
# 	 path: ./data/datasets/forms/a01-072u.png
#
# 	 unq images: 618
#
# 	 unq images: 619
#
# 	 unq images: 621
#
# 	 path: ./data/datasets/forms/m02-109.png
#
# 	 unq images: 622
#
# 	 path: ./data/datasets/forms/f04-100.png
#
# 	 unq images: 623
#
# 	 unq images: 624
#
# 	 path: ./data/datasets/forms/r06-126.png
#
# 	 unq images: 626
#
# 	 path: ./data/datasets/forms/c03-084a.png
#
# 	 unq images: 627
#
# 	 path: ./data/datasets/forms/n02-098.png
#
# 	 unq images: 629
#
# 	 path: ./data/datasets/forms/e07-061.png
#
# 	 unq images: 630
#
# 	 path: ./data/datasets/forms/p06-104.png
#
# 	 unq images: 631
#
# 	 path: ./data/datasets/forms/a01-072x.png
#
# 	 unq images: 633
#
# 	 path: ./data/datasets/forms/p06-042.png
#
# 	 unq images: 634
#
# 	 path: ./data/datasets/forms/m04-072.png
#
# 	 unq images: 635
#
# 	 path: ./data/datasets/forms/r03-065.png
#
# 	 unq images: 636
#
# 	 unq images: 638
#
# 	 path: ./data/datasets/forms/p03-181.png
#
# 	 unq images: 639
#
# 	 path: ./data/datasets/forms/c03-000a.png
#
# 	 unq images: 641
#
# 	 path: ./data/datasets/forms/f07-096.png
#
# 	 unq images: 642
#
# 	 unq images: 643
#
# 	 path: ./data/datasets/forms/p02-017.png
#
# 	 unq images: 645
#
# 	 path: ./data/datasets/forms/b05-017.png
#
# 	 unq images: 646
#
# 	 unq images: 648
#
# 	 path: ./data/datasets/forms/a05-013.png
#
# 	 unq images: 649
#
# 	 path: ./data/datasets/forms/m01-125.png
#
# 	 unq images: 650
#
# 	 path: ./data/datasets/forms/a03-014.png
#
# 	 unq images: 652
#
# 	 path: ./data/datasets/forms/g03-016.png
#
# 	 unq images: 653
#
# 	 path: ./data/datasets/forms/a04-089.png
#
# 	 unq images: 655
#
# 	 path: ./data/datasets/forms/e01-059.png
#
# 	 unq images: 656
#
# 	 path: ./data/datasets/forms/a04-015.png
#
# 	 unq images: 657
#
# 	 path: ./data/datasets/forms/a01-007.png
#
# 	 unq images: 659
#
# 	 path: ./data/datasets/forms/e02-082.png
#
# 	 unq images: 660
#
# 	 path: ./data/datasets/forms/a06-134.png
#
# 	 unq images: 661
#
# 	 path: ./data/datasets/forms/m01-136.png
#
# 	 unq images: 663
#
# 	 unq images: 663
#
# 	 path: ./data/datasets/forms/c03-021a.png
#
# 	 unq images: 665
#
# 	 path: ./data/datasets/forms/e06-041.png
#
# 	 unq images: 666
#
# 	 path: ./data/datasets/forms/d05-040.png
#
# 	 unq images: 667
#
# 	 path: ./data/datasets/forms/d04-096.png
#
# 	 unq images: 668
#
# 	 unq images: 670
#
# 	 unq images: 671
#
# 	 unq images: 672
#
# 	 path: ./data/datasets/forms/e06-053.png
#
# 	 unq images: 673
#
# 	 unq images: 675
#
# 	 path: ./data/datasets/forms/d06-008.png
#
# 	 unq images: 676
#
# 	 unq images: 678
#
# 	 path: ./data/datasets/forms/r02-127.png
#
# 	 unq images: 680
#
# 	 unq images: 681
#
# 	 path: ./data/datasets/forms/a05-048.png
#
# 	 unq images: 682
#
# 	 unq images: 683
#
# 	 unq images: 685
#
# 	 path: ./data/datasets/forms/p03-158.png
#
# 	 unq images: 686
#
# 	 unq images: 688
#
# 	 path: ./data/datasets/forms/g06-011a.png
#
# 	 unq images: 688
#
# 	 path: ./data/datasets/forms/g06-011a.png
#
# 	 unq images: 690
#
# 	 path: ./data/datasets/forms/b01-089.png
#
# 	 unq images: 691
#
# 	 path: ./data/datasets/forms/c04-105.png
#
# 	 unq images: 693
#
# 	 path: ./data/datasets/forms/g04-101.png
#
# 	 unq images: 694
#
# 	 path: ./data/datasets/forms/a01-020.png
# 	 unq images: 696
#
# 	 path: ./data/datasets/forms/m03-110.png
#
# 	 unq images: 697
#
# 	 path: ./data/datasets/forms/a02-012.png
#
# 	 unq images: 698
#
# 	 path: ./data/datasets/forms/a02-116.png
#
# 	 unq images: 700
#
# 	 path: ./data/datasets/forms/d01-118.png
#
# 	 unq images: 701
#
# 	 unq images: 703
#
# 	 path: ./data/datasets/forms/b03-025.png
#
# 	 unq images: 704
#
# 	 path: ./data/datasets/forms/e06-003.png
#
# 	 unq images: 706
#
# 	 path: ./data/datasets/forms/g06-011f.png
#
# 	 unq images: 707
#
# 	 unq images: 708
#
# 	 path: ./data/datasets/forms/b02-102.png
#
# 	 unq images: 709
#
# 	 path: ./data/datasets/forms/c02-012.png
#
# 	 unq images: 711
#
# 	 path: ./data/datasets/forms/g01-074.png
#
# 	 unq images: 712
#
# 	 unq images: 714
#
# 	 path: ./data/datasets/forms/d07-096.png
#
# 	 unq images: 715
#
# 	 path: ./data/datasets/forms/r06-137.png
#
# 	 unq images: 716
#
# 	 unq images: 718
#
# 	 path: ./data/datasets/forms/c06-138.png
#
# 	 unq images: 719
#
# 	 path: ./data/datasets/forms/m04-107.png
#
# 	 unq images: 721
#
# 	 path: ./data/datasets/forms/p06-030.png
#
# 	 unq images: 722
#
# 	 unq images: 723
#
# 	 path: ./data/datasets/forms/g06-045a.png
#
# 	 unq images: 725
#
# 	 path: ./data/datasets/forms/m01-110.png
#
# 	 unq images: 726
#
# 	 path: ./data/datasets/forms/b02-035.png
#
# 	 unq images: 728
#
# 	 unq images: 729
#
# 	 path: ./data/datasets/forms/a02-106.png
#
# 	 unq images: 731
#
# 	 path: ./data/datasets/forms/f07-039b.png
#
# 	 unq images: 732
#
# 	 path: ./data/datasets/forms/g06-050a.png
#
# 	 unq images: 733
#
# 	 unq images: 735
#
# 	 path: ./data/datasets/forms/r02-117.png
#
# 	 unq images: 736
#
# 	 path: ./data/datasets/forms/d04-117.png
#
# 	 unq images: 737
#
# 	 path: ./data/datasets/forms/m02-083.png
#
# 	 unq images: 738
#
# 	 unq images: 740
#
# 	 path: ./data/datasets/forms/b01-004.png
#
# 	 unq images: 741
#
# 	 path: ./data/datasets/forms/a02-086.png
#
# 	 unq images: 743
#
# 	 unq images: 745
#
# 	 path: ./data/datasets/forms/f02-000.png
#
# 	 unq images: 746
#
# 	 path: ./data/datasets/forms/d01-060.png
#
# 	 unq images: 747
#
# 	 path: ./data/datasets/forms/c03-007e.png
#
# 	 unq images: 749
#
# 	 path: ./data/datasets/forms/e07-066.png
#
# 	 unq images: 750
#
# 	 unq images: 752
#
# 	 path: ./data/datasets/forms/g06-031k.png
#
# 	 unq images: 753
#
# 	 path: ./data/datasets/forms/c03-000f.png
#
# 	 unq images: 754
#
# 	 path: ./data/datasets/forms/a06-036.png
#
# 	 unq images: 756
#
# 	 unq images: 757
#
# 	 unq images: 759
#
# 	 path: ./data/datasets/forms/n03-097.png
#
# 	 unq images: 760
#
# 	 path: ./data/datasets/forms/m06-067.png
#
# 	 unq images: 761
#
# 	 path: ./data/datasets/forms/n04-075.png
#
# 	 unq images: 763
#
# 	 path: ./data/datasets/forms/g04-098.png
#
# 	 unq images: 764
#
# 	 path: ./data/datasets/forms/a01-043u.png
#
# 	 unq images: 765
#
# 	 path: ./data/datasets/forms/p06-088.png
#
# 	 unq images: 767
#
# 	 unq images: 768
#
# 	 path: ./data/datasets/forms/c03-016a.png
#
# 	 unq images: 769
#
# 	 path: ./data/datasets/forms/a06-008.png
#
# 	 unq images: 771
#
# 	 path: ./data/datasets/forms/a01-058x.png
#
# 	 unq images: 772
#
# 	 path: ./data/datasets/forms/e04-127.png
#
# 	 unq images: 774
#
# 	 path: ./data/datasets/forms/n04-114.png
#
# 	 unq images: 775
#
# 	 path: ./data/datasets/forms/m04-061.png
#
# 	 unq images: 776
#
# 	 unq images: 777
#
# 	 path: ./data/datasets/forms/b04-175.png
#
# 	 unq images: 779
#
# 	 unq images: 780
#
# 	 path: ./data/datasets/forms/n03-038.png
#
# 	 unq images: 782
#
# 	 unq images: 783
#
# 	 unq images: 785
#
# 	 path: ./data/datasets/forms/e07-086.png
#
# 	 unq images: 786
#
# 	 path: ./data/datasets/forms/g04-060.png
#
# 	 unq images: 787
#
# 	 path: ./data/datasets/forms/a06-095.png
#
# 	 unq images: 789
#
# 	 path: ./data/datasets/forms/c03-007d.png
#
# 	 unq images: 790
#
# 	 path: ./data/datasets/forms/c03-096c.png
#
# 	 unq images: 792
#
# 	 path: ./data/datasets/forms/c04-139.png
#
# 	 unq images: 793
#
# 	 path: ./data/datasets/forms/r06-022.png
#
# 	 unq images: 795
#
# 	 path: ./data/datasets/forms/a05-009.png
#
# 	 unq images: 796
#
# 	 unq images: 798
#
# 	 path: ./data/datasets/forms/n02-127.png
#
# 	 unq images: 799
#
# 	 path: ./data/datasets/forms/p02-131.png
#
# 	 unq images: 800
#
# 	 path: ./data/datasets/forms/g06-050m.png
#
# 	 unq images: 802
#
# 	 path: ./data/datasets/forms/a01-011.png
#
# 	 unq images: 804
#
# 	 path: ./data/datasets/forms/m03-118.png
#
# 	 unq images: 805
#
# 	 path: ./data/datasets/forms/n06-201.png
#
# 	 unq images: 806
#
# 	 path: ./data/datasets/forms/e04-119.png
#
# 	 unq images: 808
#
# 	 path: ./data/datasets/forms/n01-045.png
#
# 	 unq images: 809
#
# 	 path: ./data/datasets/forms/e02-091.png
#
# 	 unq images: 810
#
# 	 path: ./data/datasets/forms/g06-011g.png
#
# 	 unq images: 811
#
# 	 path: ./data/datasets/forms/n04-031.png
#
# 	 unq images: 813
#
# 	 path: ./data/datasets/forms/c03-096a.png
#
# 	 unq images: 814
#
# 	 unq images: 815
#
# 	 path: ./data/datasets/forms/n02-082a.png
#
# 	 unq images: 816
#
# 	 path: ./data/datasets/forms/b01-018.png
#
# 	 unq images: 818
#
# 	 path: ./data/datasets/forms/d06-067.png
#
# 	 unq images: 819
#
# 	 path: ./data/datasets/forms/c04-122.png
#
# 	 unq images: 820
#
# 	 unq images: 822
#
# 	 unq images: 823
#
# 	 path: ./data/datasets/forms/a01-043x.png
#
# 	 unq images: 825
#
# 	 path: ./data/datasets/forms/g06-047l.png
#
# 	 unq images: 826
#
# 	 path: ./data/datasets/forms/n04-130.png
#
# 	 unq images: 827
#
# 	 path: ./data/datasets/forms/e02-000.png
#
# 	 unq images: 829
#
# 	 path: ./data/datasets/forms/m02-090.png
#
# 	 unq images: 830
#
# 	 path: ./data/datasets/forms/n06-156.png
#
# 	 unq images: 831
#
# 	 path: ./data/datasets/forms/e02-025.png
#
# 	 unq images: 832
#
# 	 path: ./data/datasets/forms/f04-028.png
#
# 	 unq images: 833
#
# 	 path: ./data/datasets/forms/p01-155.png
#
# 	 unq images: 835
#
# 	 path: ./data/datasets/forms/n04-190.png
#
# 	 unq images: 836
#
# 	 unq images: 837
#
# 	 path: ./data/datasets/forms/a01-049.png
#
# 	 unq images: 838
#
# 	 unq images: 839
#
# 	 path: ./data/datasets/forms/g06-037m.png
#
# 	 unq images: 841
#
# 	 path: ./data/datasets/forms/g04-043.png
#
# 	 unq images: 842
#
# 	 path: ./data/datasets/forms/a02-078.png
#
# 	 unq images: 843
#
# 	 path: ./data/datasets/forms/a01-026x.png
#
# 	 unq images: 844
#
# 	 path: ./data/datasets/forms/d06-096.png
#
# 	 unq images: 846
#
# 	 unq images: 847
#
# 	 path: ./data/datasets/forms/e04-083.png
#
# 	 unq images: 849
#
# 	 path: ./data/datasets/forms/p01-147.png
#
# 	 unq images: 850
#
# 	 path: ./data/datasets/forms/m04-093.png
#
# 	 unq images: 851
#
# 	 path: ./data/datasets/forms/a01-026u.png
#
# 	 unq images: 852
#
# 	 path: ./data/datasets/forms/n03-064.png
#
# 	 unq images: 854
#
# 	 path: ./data/datasets/forms/m03-006.png
#
# 	 unq images: 855
#
# 	 path: ./data/datasets/forms/b01-084.png
#
# 	 unq images: 856
#
# 	 path: ./data/datasets/forms/n04-048.png
#
# 	 unq images: 858
#
# 	 unq images: 859
#
# 	 path: ./data/datasets/forms/f07-046a.png
#
# 	 unq images: 861
#
# 	 path: ./data/datasets/forms/r03-050.png
#
# 	 unq images: 862
#
# 	 path: ./data/datasets/forms/a02-093.png
#
# 	 unq images: 863
#
# 	 unq images: 865
#
# 	 path: ./data/datasets/forms/e01-081.png
#
# 	 unq images: 866
#
# 	 path: ./data/datasets/forms/a06-128.png
#
# 	 unq images: 868
#
# 	 path: ./data/datasets/forms/b06-093.png
#
# 	 unq images: 869
#
# 	 path: ./data/datasets/forms/h05-012.png
#
# 	 unq images: 871
#
# 	 path: ./data/datasets/forms/g06-050e.png
#
# 	 unq images: 872
#
# 	 unq images: 873
#
# 	 path: ./data/datasets/forms/e06-070.png
#
# 	 unq images: 875
#
# 	 path: ./data/datasets/forms/g06-042j.png
#
# 	 unq images: 876
#
# 	 path: ./data/datasets/forms/g06-018k.png
#
# 	 unq images: 877
#
# 	 path: ./data/datasets/forms/m04-190.png
#
# 	 unq images: 878
#
# 	 path: ./data/datasets/forms/p02-090.png
#
# 	 unq images: 880
#
# 	 path: ./data/datasets/forms/d01-052.png
#
# 	 unq images: 881
#
# 	 path: ./data/datasets/forms/g04-063.png
#
# 	 unq images: 882
#
# 	 path: ./data/datasets/forms/a03-043.png
#
# 	 unq images: 883
#
# 	 unq images: 885
#
# 	 path: ./data/datasets/forms/g06-018e.png
#
# 	 unq images: 886
#
# 	 path: ./data/datasets/forms/a04-072.png
#
# 	 unq images: 887
#
# 	 path: ./data/datasets/forms/c02-049.png
#
# 	 unq images: 888
#
# 	 path: ./data/datasets/forms/d01-098.png
#
# 	 unq images: 890
#
# 	 path: ./data/datasets/forms/c04-150.png
#
# 	 unq images: 891
#
# 	 path: ./data/datasets/forms/g01-043.png
#
# 	 unq images: 893
#
# 	 path: ./data/datasets/forms/a01-043.png
#
# 	 unq images: 894
#
# 	 path: ./data/datasets/forms/f07-042b.png
#
# 	 unq images: 896
#
# 	 path: ./data/datasets/forms/g07-079a.png
#
# 	 unq images: 897
#
# 	 unq images: 898
#
# 	 path: ./data/datasets/forms/g06-050i.png
#
# 	 unq images: 899
#
# 	 path: ./data/datasets/forms/c04-110.png
#
# 	 unq images: 901
#
# 	 path: ./data/datasets/forms/e02-074.png
#
# 	 unq images: 902
#
# 	 path: ./data/datasets/forms/g06-042h.png
#
# 	 unq images: 903
#
# 	 path: ./data/datasets/forms/f03-169.png
#
# 	 unq images: 905
#
# 	 path: ./data/datasets/forms/e01-113.png
#
# 	 unq images: 906
#
# 	 path: ./data/datasets/forms/m04-138.png
#
# 	 unq images: 908
#
# 	 path: ./data/datasets/forms/c06-011.png
#
# 	 unq images: 909
#
# 	 path: ./data/datasets/forms/n02-016.png
#
# 	 unq images: 910
#
# 	 path: ./data/datasets/forms/g06-050j.png
#
# 	 unq images: 912
#
# 	 path: ./data/datasets/forms/g06-042f.png
#
# 	 unq images: 913
#
# 	 path: ./data/datasets/forms/n02-146.png
#
# 	 unq images: 914
#
# 	 unq images: 916
#
# 	 path: ./data/datasets/forms/b05-067.png
#
# 	 unq images: 917
#
# 	 path: ./data/datasets/forms/f07-028b.png
#
# 	 unq images: 918
#
# 	 path: ./data/datasets/forms/g06-045j.png
# 	 unq images: 920
#
# 	 unq images: 921
#
# 	 unq images: 922
#
# 	 unq images: 923
#
# 	 path: ./data/datasets/forms/p03-087.png
#
# 	 unq images: 924
#
# 	 unq images: 926
#
# 	 path: ./data/datasets/forms/a01-049u.png
#
# 	 unq images: 927
#
# 	 path: ./data/datasets/forms/d01-049.png
#
# 	 unq images: 929
#
# 	 path: ./data/datasets/forms/r03-030.png
#
# 	 unq images: 930
#
# 	 path: ./data/datasets/forms/a05-069.png
#
# 	 unq images: 931
#
# 	 unq images: 933
#
# 	 path: ./data/datasets/forms/h04-025.png
#
# 	 unq images: 934
#
# 	 path: ./data/datasets/forms/e04-026.png
#
# 	 unq images: 935
#
# 	 path: ./data/datasets/forms/d04-021.png
#
# 	 unq images: 936
#
# 	 path: ./data/datasets/forms/p01-168.png
#
# 	 unq images: 938
#
# 	 path: ./data/datasets/forms/e04-091.png
#
# 	 unq images: 939
#
# 	 path: ./data/datasets/forms/b06-045.png
#
# 	 unq images: 941
#
# 	 path: ./data/datasets/forms/g06-050f.png
#
# 	 unq images: 942
#
# 	 path: ./data/datasets/forms/c04-134.png
#
# 	 unq images: 943
#
# 	 path: ./data/datasets/forms/d07-082.png
#
# 	 unq images: 945
#
# 	 unq images: 946
#
# 	 path: ./data/datasets/forms/f04-011.png
#
# 	 unq images: 947
#
# 	 path: ./data/datasets/forms/c03-007b.png
#
# 	 unq images: 948
#
# 	 path: ./data/datasets/forms/n03-091.png
#
# 	 unq images: 949
#
# 	 path: ./data/datasets/forms/c04-044.png
#
# 	 unq images: 951
#
# 	 path: ./data/datasets/forms/b06-023.png
#
# 	 unq images: 952
#
# 	 path: ./data/datasets/forms/d05-030.png
#
# 	 unq images: 954
#
# 	 path: ./data/datasets/forms/g03-049.png
#
# 	 unq images: 955
#
# 	 unq images: 956
#
# 	 path: ./data/datasets/forms/e07-094.png
#
# 	 unq images: 957
#
# 	 path: ./data/datasets/forms/r03-110.png
#
# 	 unq images: 959
#
# 	 unq images: 960
#
# 	 unq images: 961
#
# 	 path: ./data/datasets/forms/g06-031d.png
#
# 	 unq images: 963
#
# 	 path: ./data/datasets/forms/f07-088b.png
#
# 	 unq images: 965
#
# 	 path: ./data/datasets/forms/n04-084.png
#
# 	 unq images: 966
#
# 	 path: ./data/datasets/forms/p03-012.png
#
# 	 unq images: 967
#
# 	 path: ./data/datasets/forms/a01-058.png
#
# 	 unq images: 969
#
# 	 unq images: 970
#
# 	 path: ./data/datasets/forms/f07-032b.png
#
# 	 unq images: 971
#
# 	 path: ./data/datasets/forms/c02-022.png
#
# 	 unq images: 973
#
# 	 path: ./data/datasets/forms/a01-107u.png
#
# 	 unq images: 974
#
# 	 path: ./data/datasets/forms/d04-008.png
#
# 	 unq images: 976
#
# 	 path: ./data/datasets/forms/c03-000e.png
#
# 	 unq images: 977
#
# 	 path: ./data/datasets/forms/r06-106.png
#
# 	 unq images: 979
#
# 	 path: ./data/datasets/forms/a06-004.png
#
# 	 unq images: 980
#
# 	 path: ./data/datasets/forms/e02-014.png
#
# 	 unq images: 982
#
# 	 path: ./data/datasets/forms/g06-011l.png
#
# 	 unq images: 982
#
# 	 path: ./data/datasets/forms/g06-011l.png
#
# 	 unq images: 984
#
# 	 path: ./data/datasets/forms/p03-096.png
#
# 	 unq images: 985
#
# 	 path: ./data/datasets/forms/f02-038.png
#
# 	 unq images: 987
#
# 	 path: ./data/datasets/forms/n04-149.png
#
# 	 unq images: 988
#
# 	 path: ./data/datasets/forms/g06-042d.png
#
# 	 unq images: 990
#
# 	 path: ./data/datasets/forms/p02-027.png
#
# 	 unq images: 991
#
# 	 path: ./data/datasets/forms/m06-098.png
#
# 	 unq images: 992
#
# 	 unq images: 993
#
# 	 path: ./data/datasets/forms/n04-163.png
#
# 	 unq images: 995
#
# 	 unq images: 996
#
# 	 unq images: 997
#
# 	 path: ./data/datasets/forms/n04-044.png
#
# 	 unq images: 999
#
# 	 path: ./data/datasets/forms/a06-025.png
#
# 	 unq images: 1000
#
# 	 path: ./data/datasets/forms/a06-090.png
#
# 	 unq images: 1002
#
# 	 unq images: 1003
#
# 	 unq images: 1004
#
# 	 unq images: 1006
#
# 	 path: ./data/datasets/forms/d06-027.png
#
# 	 unq images: 1007
#
# 	 path: ./data/datasets/forms/p03-151.png
#
# 	 unq images: 1009
#
# 	 path: ./data/datasets/forms/g06-050h.png
#
# 	 unq images: 1010
#
# 	 path: ./data/datasets/forms/f04-074.png
#
# 	 unq images: 1011
#
# 	 path: ./data/datasets/forms/f02-017.png
#
# 	 unq images: 1012
#
# 	 path: ./data/datasets/forms/a05-084.png
#
# 	 unq images: 1013
#
# 	 path: ./data/datasets/forms/r06-090.png
#
# 	 unq images: 1015
#
# 	 path: ./data/datasets/forms/b06-012.png
#
# 	 unq images: 1016
#
# 	 path: ./data/datasets/forms/e01-014.png
#
# 	 unq images: 1018
#
# 	 path: ./data/datasets/forms/e04-015.png
#
# 	 unq images: 1019
#
# 	 path: ./data/datasets/forms/c04-160.png
#
# 	 unq images: 1021
#
# 	 path: ./data/datasets/forms/e02-021.png
#
# 	 unq images: 1022
#
# 	 path: ./data/datasets/forms/d04-075.png
#
# 	 unq images: 1024
#
# 	 path: ./data/datasets/forms/c06-106.png
#
# 	 unq images: 1025
#
# 	 path: ./data/datasets/forms/d03-117.png
#
# 	 unq images: 1026
#
# 	 path: ./data/datasets/forms/a05-044.png
#
# 	 unq images: 1028
#
# 	 path: ./data/datasets/forms/g04-011.png
#
# 	 unq images: 1029
#
# 	 path: ./data/datasets/forms/n01-009.png
#
# 	 unq images: 1030
#
# 	 unq images: 1032
#
# 	 path: ./data/datasets/forms/f07-019a.png
#
# 	 unq images: 1033
#
# 	 path: ./data/datasets/forms/e04-058.png
#
# 	 unq images: 1034
#
# 	 path: ./data/datasets/forms/g06-011j.png
#
# 	 unq images: 1036
#
# 	 path: ./data/datasets/forms/g06-047c.png
#
# 	 unq images: 1037
#
# 	 path: ./data/datasets/forms/g06-042m.png
#
# 	 unq images: 1039
#
# 	 path: ./data/datasets/forms/n02-054.png
#
# 	 unq images: 1040
#
# 	 path: ./data/datasets/forms/r06-003.png
#
# 	 unq images: 1041
#
# 	 path: ./data/datasets/forms/b04-169.png
#
# 	 unq images: 1042
#
# 	 path: ./data/datasets/forms/c03-087c.png
#
# 	 unq images: 1043
#
# 	 unq images: 1045
#
# 	 path: ./data/datasets/forms/n02-028.png
#
# 	 unq images: 1046
#
# 	 unq images: 1047
#
# 	 unq images: 1048
#
# 	 path: ./data/datasets/forms/g06-031f.png
#
# 	 unq images: 1050
#
# 	 unq images: 1051
#
# 	 path: ./data/datasets/forms/e06-021.png
#
# 	 unq images: 1053
#
# 	 path: ./data/datasets/forms/c06-005.png
#
# 	 unq images: 1054
#
# 	 path: ./data/datasets/forms/d04-016.png
#
# 	 unq images: 1055
#
# 	 path: ./data/datasets/forms/g06-050b.png
#
# 	 unq images: 1057
#
# 	 unq images: 1058
#
# 	 path: ./data/datasets/forms/c01-014.png
#
# 	 unq images: 1059
#
# 	 path: ./data/datasets/forms/e04-011.png
#
# 	 unq images: 1060
#
# 	 unq images: 1062
#
# 	 path: ./data/datasets/forms/a01-014x.png
#
# 	 unq images: 1063
#
# 	 path: ./data/datasets/forms/n06-169.png
#
# 	 unq images: 1064
#
# 	 unq images: 1066
#
# 	 path: ./data/datasets/forms/m01-104.png
#
# 	 unq images: 1067
#
# 	 path: ./data/datasets/forms/e06-010.png
#
# 	 unq images: 1068
#
# 	 path: ./data/datasets/forms/n04-195.png
#
# 	 unq images: 1070
#
# 	 path: ./data/datasets/forms/b05-032.png
#
# 	 unq images: 1071
#
# 	 path: ./data/datasets/forms/b04-187.png
#
# 	 unq images: 1072
#
# 	 path: ./data/datasets/forms/d04-125.png
#
# 	 unq images: 1073
#
# 	 path: ./data/datasets/forms/g06-031a.png
#
# 	 unq images: 1075
#
# 	 path: ./data/datasets/forms/c02-007.png
#
# 	 unq images: 1076
#
# 	 unq images: 1078
#
# 	 path: ./data/datasets/forms/c01-066.png
#
# 	 unq images: 1079
#
# 	 unq images: 1080
#
# 	 path: ./data/datasets/forms/g06-045e.png
#
# 	 unq images: 1082
#
# 	 path: ./data/datasets/forms/g01-016.png
#
# 	 unq images: 1083
#
# 	 path: ./data/datasets/forms/a04-099.png
#
# 	 unq images: 1084
#
# 	 unq images: 1086
#
# 	 path: ./data/datasets/forms/c03-003d.png
#
# 	 unq images: 1087
#
# 	 path: ./data/datasets/forms/r03-007.png
#
# 	 unq images: 1088
#
# 	 path: ./data/datasets/forms/a02-111.png
#
# 	 unq images: 1090
#
# 	 path: ./data/datasets/forms/c06-031.png
#
# 	 unq images: 1091
#
# 	 path: ./data/datasets/forms/r06-076.png
#
# 	 unq images: 1093
#
# 	 path: ./data/datasets/forms/a03-073.png
#
# 	 unq images: 1094
#
# 	 path: ./data/datasets/forms/m04-113.png
#
# 	 unq images: 1095
#
# 	 unq images: 1097
#
# 	 path: ./data/datasets/forms/a02-072.png
#
# 	 unq images: 1098
#
# 	 path: ./data/datasets/forms/f04-004.png
#
# 	 unq images: 1099
#
# 	 path: ./data/datasets/forms/g06-026l.png
#
# 	 unq images: 1101
#
# 	 path: ./data/datasets/forms/d06-104.png
#
# 	 unq images: 1102
#
# 	 path: ./data/datasets/forms/r03-035.png
#
# 	 unq images: 1103
#
# 	 path: ./data/datasets/forms/a04-047.png
#
# 	 unq images: 1104
#
# 	 unq images: 1105
#
# 	 path: ./data/datasets/forms/m02-055.png
#
# 	 unq images: 1107
#
# 	 unq images: 1108
#
# 	 path: ./data/datasets/forms/b01-038.png
#
# 	 unq images: 1109
#
# 	 path: ./data/datasets/forms/b06-071.png
#
# 	 unq images: 1110
#
# 	 path: ./data/datasets/forms/d04-028.png
#
# 	 unq images: 1111
#
# 	 path: ./data/datasets/forms/b03-109.png
#
# 	 unq images: 1113
#
# 	 unq images: 1114
#
# 	 path: ./data/datasets/forms/c03-016b.png
#
# 	 unq images: 1115
#
# 	 unq images: 1117
#
# 	 path: ./data/datasets/forms/p03-057.png
#
# 	 unq images: 1118
#
# 	 path: ./data/datasets/forms/e04-000.png
#
# 	 unq images: 1119
#
# 	 path: ./data/datasets/forms/g02-059.png
#
# 	 unq images: 1120
#
# 	 path: ./data/datasets/forms/f07-073.png
#
# 	 unq images: 1122
#
# 	 path: ./data/datasets/forms/b01-014.png
#
# 	 unq images: 1123
#
# 	 path: ./data/datasets/forms/n06-082.png
#
# 	 unq images: 1124
#
# 	 path: ./data/datasets/forms/a01-063.png
#
# 	 unq images: 1125
#
# 	 path: ./data/datasets/forms/g04-036.png
#
# 	 unq images: 1127
#
# 	 path: ./data/datasets/forms/r06-027.png
#
# 	 unq images: 1128
#
# 	 unq images: 1129
#
# 	 path: ./data/datasets/forms/g06-026m.png
#
# 	 unq images: 1131
#
# 	 path: ./data/datasets/forms/g02-065.png
#
# 	 unq images: 1132
#
# 	 path: ./data/datasets/forms/g04-077.png
#
# 	 unq images: 1134
#
# 	 path: ./data/datasets/forms/m03-033.png
#
# 	 unq images: 1135
#
# 	 path: ./data/datasets/forms/c03-087b.png
#
# 	 unq images: 1136
#
# 	 path: ./data/datasets/forms/a04-031.png
#
# 	 unq images: 1138
#
# 	 path: ./data/datasets/forms/g06-045l.png
# 	 unq images: 1139
#
# 	 path: ./data/datasets/forms/c06-076.png
#
# 	 unq images: 1140
#
# 	 path: ./data/datasets/forms/c04-089.png
#
# 	 unq images: 1141
#
# 	 path: ./data/datasets/forms/c02-059.png
#
# 	 unq images: 1143
#
# 	 unq images: 1144
#
# 	 path: ./data/datasets/forms/r02-006.png
#
# 	 unq images: 1146
#
# 	 path: ./data/datasets/forms/g06-047e.png
#
# 	 unq images: 1147
#
# 	 path: ./data/datasets/forms/a03-059.png
#
# 	 unq images: 1148
#
# 	 path: ./data/datasets/forms/g06-018d.png
#
# 	 unq images: 1150
#
# 	 path: ./data/datasets/forms/g06-045m.png
#
# 	 unq images: 1151
#
# 	 unq images: 1152
#
# 	 path: ./data/datasets/forms/f07-009.png
#
# 	 unq images: 1153
#
# 	 path: ./data/datasets/forms/m06-031.png
#
# 	 unq images: 1155
#
# 	 path: ./data/datasets/forms/d01-019.png
#
# 	 unq images: 1156
#
# 	 unq images: 1157
#
# 	 path: ./data/datasets/forms/c02-026.png
#
# 	 unq images: 1158
#
# 	 path: ./data/datasets/forms/a06-064.png
#
# 	 unq images: 1160
#
# 	 path: ./data/datasets/forms/n02-004.png
#
# 	 unq images: 1161
#
# 	 path: ./data/datasets/forms/c03-084d.png
#
# 	 unq images: 1162
#
# 	 path: ./data/datasets/forms/c03-007a.png
#
# 	 unq images: 1164
#
# 	 unq images: 1165
#
# 	 path: ./data/datasets/forms/f04-083.png
#
# 	 unq images: 1166
#
# 	 path: ./data/datasets/forms/a01-102.png
#
# 	 unq images: 1167
#
# 	 path: ./data/datasets/forms/e07-072.png
#
# 	 unq images: 1168
#
# 	 path: ./data/datasets/forms/p06-058.png
#
# 	 unq images: 1170
#
# 	 path: ./data/datasets/forms/a03-020.png
#
# 	 unq images: 1172
#
# 	 path: ./data/datasets/forms/e06-037.png
#
# 	 unq images: 1173
#
# 	 path: ./data/datasets/forms/p03-033.png
#
# 	 unq images: 1174
#
# 	 unq images: 1176
#
# 	 unq images: 1177
#
# 	 unq images: 1179
#
# 	 path: ./data/datasets/forms/a05-073.png
#
# 	 unq images: 1180
#
# 	 path: ./data/datasets/forms/b05-038.png
#
# 	 unq images: 1181
#
# 	 unq images: 1182
#
# 	 path: ./data/datasets/forms/p02-000.png
#
# 	 unq images: 1184
#
# 	 path: ./data/datasets/forms/b04-026.png
#
# 	 unq images: 1185
#
# 	 path: ./data/datasets/forms/a05-099.png
#
# 	 unq images: 1186
#
# 	 unq images: 1187
#
# 	 unq images: 1189
#
# 	 path: ./data/datasets/forms/m01-121.png
#
# 	 unq images: 1190
#
# 	 path: ./data/datasets/forms/g06-047k.png
#
# 	 unq images: 1191
#
# 	 path: ./data/datasets/forms/c04-128.png
#
# 	 unq images: 1193
#
# 	 path: ./data/datasets/forms/m02-066.png
#
# 	 unq images: 1194
#
# 	 path: ./data/datasets/forms/g06-047f.png
#
# 	 unq images: 1195
#
# 	 path: ./data/datasets/forms/g06-011i.png
#
# 	 unq images: 1197
#
# 	 path: ./data/datasets/forms/g03-000.png
#
# 	 unq images: 1198
#
# 	 path: ./data/datasets/forms/f07-069.png
#
# 	 unq images: 1199
#
# 	 path: ./data/datasets/forms/r03-002.png
#
# 	 unq images: 1200
#
# 	 path: ./data/datasets/forms/p02-127.png
#
# 	 unq images: 1201
#
# 	 path: ./data/datasets/forms/c03-003b.png
#
# 	 unq images: 1203
#
# 	 unq images: 1204
#
# 	 path: ./data/datasets/forms/m04-238.png
#
# 	 unq images: 1206
#
# 	 path: ./data/datasets/forms/f01-143.png
#
# 	 unq images: 1207
#
# 	 path: ./data/datasets/forms/n01-052.png
#
# 	 unq images: 1208
#
# 	 path: ./data/datasets/forms/a04-027.png
#
# 	 unq images: 1210
#
# 	 path: ./data/datasets/forms/g01-027.png
#
# 	 unq images: 1211
#
# 	 path: ./data/datasets/forms/d04-089.png
#
# 	 unq images: 1212
#
# 	 path: ./data/datasets/forms/b06-110.png
#
# 	 unq images: 1214
#
# 	 unq images: 1215
#
# 	 path: ./data/datasets/forms/g06-042k.png
#
# 	 unq images: 1216
#
# 	 path: ./data/datasets/forms/d04-058.png
#
# 	 unq images: 1218
#
# 	 path: ./data/datasets/forms/m04-012.png
#
# 	 unq images: 1219
#
# 	 path: ./data/datasets/forms/e01-102.png
#
# 	 unq images: 1220
#
# 	 unq images: 1222
#
# 	 path: ./data/datasets/forms/p06-096.png
#
# 	 unq images: 1223
#
# 	 path: ./data/datasets/forms/c04-017.png
#
# 	 unq images: 1224
#
# 	 path: ./data/datasets/forms/b02-045.png
#
# 	 unq images: 1225
#
# 	 path: ./data/datasets/forms/m04-152.png
#
# 	 unq images: 1227
#
# 	 path: ./data/datasets/forms/g01-004.png
#
# 	 unq images: 1228
#
# 	 path: ./data/datasets/forms/b04-096.png
#
# 	 unq images: 1230
#
# 	 path: ./data/datasets/forms/b05-058.png
#
# 	 unq images: 1231
#
# 	 path: ./data/datasets/forms/a06-152.png
#
# 	 unq images: 1233
#
# 	 unq images: 1234
#
# 	 unq images: 1235
#
# 	 path: ./data/datasets/forms/b05-098.png
#
# 	 unq images: 1236
#
# 	 path: ./data/datasets/forms/r02-013.png
#
# 	 unq images: 1238
#
# 	 path: ./data/datasets/forms/e01-035.png
#
# 	 unq images: 1239
#
# 	 unq images: 1240
#
# 	 unq images: 1242
#
# 	 path: ./data/datasets/forms/b04-128.png
#
# 	 unq images: 1243
#
# 	 path: ./data/datasets/forms/g06-037e.png
#
# 	 unq images: 1244
#
# 	 path: ./data/datasets/forms/f07-021b.png
#
# 	 unq images: 1246
#
# 	 unq images: 1247
#
# 	 path: ./data/datasets/forms/g06-037i.png
#
# 	 unq images: 1248
#
# 	 unq images: 1250
#
# 	 unq images: 1251
#
# 	 path: ./data/datasets/forms/r06-070.png
#
# 	 unq images: 1253
#
# 	 path: ./data/datasets/forms/d04-111.png
#
# 	 unq images: 1253
#
# 	 path: ./data/datasets/forms/d04-111.png
#
# 	 unq images: 1255
#
# 	 path: ./data/datasets/forms/d07-085.png
#
# 	 unq images: 1256
#
# 	 path: ./data/datasets/forms/f07-016.png
#
# 	 unq images: 1258
#
# 	 path: ./data/datasets/forms/n02-109.png
#
# 	 unq images: 1259
#
# 	 path: ./data/datasets/forms/c06-116.png
#
# 	 unq images: 1261
#
# 	 path: ./data/datasets/forms/m02-080.png
#
# 	 unq images: 1262
#
# 	 path: ./data/datasets/forms/p03-009.png
#
# 	 unq images: 1263
#
# 	 unq images: 1264
#
# 	 path: ./data/datasets/forms/c02-078.png
#
# 	 unq images: 1266
#
# 	 path: ./data/datasets/forms/b06-008.png
#
# 	 unq images: 1267
#
# 	 path: ./data/datasets/forms/n06-074.png
#
# 	 unq images: 1268
#
# 	 path: ./data/datasets/forms/f01-066.png
#
# 	 unq images: 1269
#
# 	 path: ./data/datasets/forms/a04-035.png
#
# 	 unq images: 1270
#
# 	 path: ./data/datasets/forms/r02-070.png
#
# 	 unq images: 1272
#
# 	 path: ./data/datasets/forms/b06-059.png
#
# 	 unq images: 1273
#
# 	 path: ./data/datasets/forms/g06-018h.png
#
# 	 unq images: 1274
#
# 	 path: ./data/datasets/forms/c03-081b.png
#
# 	 unq images: 1276
#
# 	 unq images: 1277
#
# 	 path: ./data/datasets/forms/e01-119.png
#
# 	 unq images: 1278
#
# 	 path: ./data/datasets/forms/g06-045g.png
#
# 	 unq images: 1279
#
# 	 path: ./data/datasets/forms/r03-084.png
#
# 	 unq images: 1281
#
# 	 path: ./data/datasets/forms/d05-025.png
#
# 	 unq images: 1282
#
# 	 unq images: 1283
#
# 	 path: ./data/datasets/forms/a04-010.png
#
# 	 unq images: 1285
#
# 	 path: ./data/datasets/forms/b05-050.png
#
# 	 unq images: 1286
#
# 	 path: ./data/datasets/forms/p02-081.png
#
# 	 unq images: 1288
#
# 	 path: ./data/datasets/forms/e04-034.png
#
# 	 unq images: 1289
#
# 	 path: ./data/datasets/forms/m04-081.png
#
# 	 unq images: 1290
#
# 	 unq images: 1291
#
# 	 path: ./data/datasets/forms/f04-020.png
#
# 	 unq images: 1293
#
# 	 path: ./data/datasets/forms/f01-139.png
#
# 	 unq images: 1294
#
# 	 path: ./data/datasets/forms/f01-147.png
#
# 	 unq images: 1296
#
# 	 unq images: 1298
#
# 	 path: ./data/datasets/forms/f07-092b.png
#
# 	 unq images: 1299
#
# 	 unq images: 1301
#
# 	 path: ./data/datasets/forms/p02-144.png
#
# 	 unq images: 1302
#
# 	 path: ./data/datasets/forms/d05-013.png
#
# 	 unq images: 1303
#
# 	 path: ./data/datasets/forms/g01-019.png
#
# 	 unq images: 1305
#
# 	 path: ./data/datasets/forms/a02-046.png
#
# 	 unq images: 1306
#
# 	 path: ./data/datasets/forms/b04-195.png
#
# 	 unq images: 1308
#
# 	 path: ./data/datasets/forms/g06-026a.png
#
# 	 unq images: 1309
#
# 	 unq images: 1310
#
# 	 unq images: 1312
#
# 	 unq images: 1313
#
# 	 path: ./data/datasets/forms/m02-048.png
#
# 	 unq images: 1314
#
# 	 unq images: 1315
#
# 	 path: ./data/datasets/forms/p02-150.png
#
# 	 unq images: 1316
#
# 	 unq images: 1317
#
# 	 path: ./data/datasets/forms/e06-033.png
#
# 	 unq images: 1318
#
# 	 unq images: 1319
#
# 	 path: ./data/datasets/forms/m04-123.png
#
# 	 unq images: 1321
#
# 	 unq images: 1322
#
# 	 path: ./data/datasets/forms/b06-042.png
#
# 	 unq images: 1323
#
# 	 path: ./data/datasets/forms/c03-016d.png
#
# 	 unq images: 1324
#
# 	 path: ./data/datasets/forms/d06-091.png
#
# 	 unq images: 1325
#
# 	 path: ./data/datasets/forms/n02-040.png
#
# 	 unq images: 1327
#
# 	 unq images: 1328
#
# 	 path: ./data/datasets/forms/a05-004.png
#
# 	 unq images: 1329
#
# 	 unq images: 1331
#
# 	 path: ./data/datasets/forms/c03-094a.png
#
# 	 unq images: 1332
#
# 	 path: ./data/datasets/forms/f04-057.png
#
# 	 unq images: 1333
#
# 	 path: ./data/datasets/forms/n02-120.png
#
# 	 unq images: 1335
#
# 	 unq images: 1336
#
# 	 path: ./data/datasets/forms/p03-163.png
#
# 	 unq images: 1337
#
# 	 path: ./data/datasets/forms/g06-037j.png
#
# 	 unq images: 1339
#
# 	 path: ./data/datasets/forms/c02-030.png
#
# 	 unq images: 1340
#
# 	 path: ./data/datasets/forms/a05-121.png
#
# 	 unq images: 1342
#
# 	 path: ./data/datasets/forms/a01-087u.png
#
# 	 unq images: 1343
#
# 	 unq images: 1345
#
# 	 path: ./data/datasets/forms/g03-040.png
#
# 	 unq images: 1346
#
# 	 path: ./data/datasets/forms/c03-081d.png
#
# 	 unq images: 1347
#
# 	 path: ./data/datasets/forms/b01-073.png
#
# 	 unq images: 1348
#
# 	 unq images: 1350
#
# 	 unq images: 1351
#
# 	 path: ./data/datasets/forms/r03-053.png
#
# 	 unq images: 1352
#
# 	 path: ./data/datasets/forms/a01-026.png
# 	 unq images: 1353
#
# 	 unq images: 1355
#
# 	 path: ./data/datasets/forms/n06-133.png
#
# 	 unq images: 1356
#
# 	 path: ./data/datasets/forms/m01-115.png
#
# 	 unq images: 1357
#
# 	 path: ./data/datasets/forms/f07-024a.png
#
# 	 unq images: 1358
#
# 	 path: ./data/datasets/forms/c03-096d.png
#
# 	 unq images: 1360
#
# 	 path: ./data/datasets/forms/p06-242.png
#
# 	 unq images: 1361
#
# 	 path: ./data/datasets/forms/m06-106.png
#
# 	 unq images: 1362
#
# 	 path: ./data/datasets/forms/n03-106.png
#
# 	 unq images: 1364
#
# 	 path: ./data/datasets/forms/p03-103.png
#
# 	 unq images: 1365
#
# 	 path: ./data/datasets/forms/g06-045k.png
#
# 	 unq images: 1367
#
# 	 path: ./data/datasets/forms/f02-040.png
#
# 	 unq images: 1368
#
# 	 path: ./data/datasets/forms/g04-032.png
#
# 	 unq images: 1369
#
# 	 path: ./data/datasets/forms/b04-060.png
#
# 	 unq images: 1370
#
# 	 path: ./data/datasets/forms/g04-068.png
#
# 	 unq images: 1371
#
# 	 unq images: 1373
#
# 	 path: ./data/datasets/forms/a04-085.png
#
# 	 unq images: 1374
#
# 	 path: ./data/datasets/forms/a06-057.png
#
# 	 unq images: 1376
#
# 	 path: ./data/datasets/forms/g04-003.png
#
# 	 unq images: 1377
#
# 	 path: ./data/datasets/forms/f07-084a.png
#
# 	 unq images: 1378
#
# 	 path: ./data/datasets/forms/c03-003a.png
#
# 	 unq images: 1380
#
# 	 path: ./data/datasets/forms/a02-102.png
#
# 	 unq images: 1381
#
# 	 path: ./data/datasets/forms/m04-246.png
#
# 	 unq images: 1382
#
# 	 path: ./data/datasets/forms/f07-000b.png
#
# 	 unq images: 1384
#
# 	 path: ./data/datasets/forms/e04-043.png
#
# 	 unq images: 1385
#
# 	 unq images: 1387
#
# 	 path: ./data/datasets/forms/e07-108.png
#
# 	 unq images: 1388
#
# 	 path: ./data/datasets/forms/g06-050g.png
#
# 	 unq images: 1389
#
# 	 path: ./data/datasets/forms/e04-052.png
#
# 	 unq images: 1390
#
# 	 path: ./data/datasets/forms/a05-025.png
#
# 	 unq images: 1391
#
# 	 unq images: 1393
#
# 	 path: ./data/datasets/forms/c04-066.png
#
# 	 unq images: 1394
#
# 	 path: ./data/datasets/forms/n03-103.png
#
# 	 unq images: 1395
#
# 	 path: ./data/datasets/forms/a03-050.png
#
# 	 unq images: 1396
#
# 	 path: ./data/datasets/forms/a02-057.png
#
# 	 unq images: 1398
#
# 	 unq images: 1399
#
# 	 path: ./data/datasets/forms/a01-007x.png
#
# 	 unq images: 1401
#
# 	 path: ./data/datasets/forms/b01-079.png
#
# 	 unq images: 1402
#
# 	 unq images: 1403
#
# 	 path: ./data/datasets/forms/g06-047b.png
#
# 	 unq images: 1405
#
# 	 unq images: 1406
#
# 	 path: ./data/datasets/forms/f02-020.png
#
# 	 unq images: 1407
#
# 	 unq images: 1408
#
# 	 path: ./data/datasets/forms/p03-069.png
#
# 	 unq images: 1410
#
# 	 path: ./data/datasets/forms/r02-010.png
#
# 	 unq images: 1412
#
# 	 unq images: 1413
#
# 	 path: ./data/datasets/forms/f04-061.png
#
# 	 unq images: 1414
#
# 	 path: ./data/datasets/forms/f07-021a.png
#
# 	 unq images: 1416
#
# 	 path: ./data/datasets/forms/b06-000.png
#
# 	 unq images: 1417
#
# 	 unq images: 1419
#
# 	 path: ./data/datasets/forms/a05-104.png
#
# 	 unq images: 1420
#
# 	 path: ./data/datasets/forms/n04-100.png
#
# 	 unq images: 1422
#
# 	 path: ./data/datasets/forms/p02-022.png
#
# 	 unq images: 1423
#
# 	 unq images: 1424
#
# 	 path: ./data/datasets/forms/b05-083.png
#
# 	 unq images: 1425
#
# 	 path: ./data/datasets/forms/p02-115.png
#
# 	 unq images: 1427
#
# 	 path: ./data/datasets/forms/c02-000.png
#
# 	 unq images: 1428
#
# 	 path: ./data/datasets/forms/d06-111.png
#
# 	 unq images: 1429
#
# 	 path: ./data/datasets/forms/p03-029.png
#
# 	 unq images: 1431
#
# 	 path: ./data/datasets/forms/e06-046.png
#
# 	 unq images: 1432
#
# 	 path: ./data/datasets/forms/f02-044.png
#
# 	 unq images: 1433
#
# 	 path: ./data/datasets/forms/n01-057.png
#
# 	 unq images: 1434
#
# 	 unq images: 1436
#
# 	 path: ./data/datasets/forms/c06-000.png
#
# 	 unq images: 1437
#
# 	 path: ./data/datasets/forms/r06-066.png
#
# 	 unq images: 1439
#
# 	 path: ./data/datasets/forms/d06-030.png
#
# 	 unq images: 1440
#
# 	 path: ./data/datasets/forms/b04-081.png
#
# 	 unq images: 1441
#
# 	 unq images: 1443
#
# 	 path: ./data/datasets/forms/f07-000.png
#
# 	 unq images: 1444
#
# 	 path: ./data/datasets/forms/g06-018g.png
#
# 	 unq images: 1446
#
# 	 path: ./data/datasets/forms/g06-042l.png
#
# 	 unq images: 1447
#
# 	 path: ./data/datasets/forms/a04-039.png
#
# 	 unq images: 1449
#
# 	 path: ./data/datasets/forms/m02-059.png
#
# 	 unq images: 1450
#
# 	 path: ./data/datasets/forms/g06-045d.png
#
# 	 unq images: 1451
#
# 	 path: ./data/datasets/forms/b06-019.png
#
# 	 unq images: 1452
#
# 	 unq images: 1454
#
# 	 path: ./data/datasets/forms/d06-020.png
#
# 	 unq images: 1455
#
# 	 path: ./data/datasets/forms/n04-068.png
#
# 	 unq images: 1456
#
# 	 path: ./data/datasets/forms/c03-016c.png
#
# 	 unq images: 1458
#
# 	 path: ./data/datasets/forms/g06-050c.png
#
# 	 unq images: 1459
#
# 	 path: ./data/datasets/forms/c02-082.png
#
# 	 unq images: 1461
#
# 	 path: ./data/datasets/forms/e04-038.png
#
# 	 unq images: 1462
#
# 	 path: ./data/datasets/forms/a06-075.png
#
# 	 unq images: 1464
#
# 	 unq images: 1465
#
# 	 path: ./data/datasets/forms/e01-032.png
#
# 	 unq images: 1466
#
# 	 unq images: 1468
#
# 	 path: ./data/datasets/forms/a04-023.png
#
# 	 unq images: 1469
#
# 	 path: ./data/datasets/forms/f07-019b.png
#
# 	 unq images: 1470
#
# 	 path: ./data/datasets/forms/e01-025.png
#
# 	 unq images: 1472
#
# 	 path: ./data/datasets/forms/f07-081a.png
#
# 	 unq images: 1473
#
# 	 unq images: 1475
#
# 	 unq images: 1476
#
# 	 unq images: 1477
#
# 	 path: ./data/datasets/forms/g06-018j.png
#
# 	 unq images: 1478
#
# 	 path: ./data/datasets/forms/p03-072.png
#
# 	 unq images: 1479
#
# 	 path: ./data/datasets/forms/b05-074.png
#
# 	 unq images: 1481
#
# 	 path: ./data/datasets/forms/n02-062.png
#
# 	 unq images: 1482
#
# 	 path: ./data/datasets/forms/d05-021.png
#
# 	 unq images: 1483
#
# 	 unq images: 1484
#
# 	 unq images: 1486
#
# 	 path: ./data/datasets/forms/d04-053.png
#
# 	 unq images: 1487
#
# 	 path: ./data/datasets/forms/c04-008.png
#
# 	 unq images: 1488
#
# 	 path: ./data/datasets/forms/c02-017.png
#
# 	 unq images: 1489
#
# 	 path: ./data/datasets/forms/a02-090.png
#
# 	 unq images: 1490
#
# 	 path: ./data/datasets/forms/d07-089.png
#
# 	 unq images: 1491
#
# 	 path: ./data/datasets/forms/g06-011h.png
#
# 	 unq images: 1492
#
# 	 unq images: 1494
#
# 	 unq images: 1495
#
# 	 path: ./data/datasets/forms/d07-093.png
#
# 	 unq images: 1497
#
# 	 path: ./data/datasets/forms/a01-020u.png
#
# 	 unq images: 1498
#
# 	 unq images: 1500
#
# 	 path: ./data/datasets/forms/a04-066.png
#
# 	 unq images: 1501
#
# 	 path: ./data/datasets/forms/e04-103.png
#
# 	 unq images: 1502
#
# 	 path: ./data/datasets/forms/h04-007.png
#
# 	 unq images: 1504
#
# 	 path: ./data/datasets/forms/p03-189.png
#
# 	 unq images: 1506
#
# 	 path: ./data/datasets/forms/g04-026.png
#
# 	 unq images: 1507
#
# 	 unq images: 1508
#
# 	 unq images: 1509
#
# 	 path: ./data/datasets/forms/a01-014.png
#
# 	 unq images: 1511
#
# 	 path: ./data/datasets/forms/b06-082.png
#
# 	 unq images: 1512
#
# 	 path: ./data/datasets/forms/d03-112.png
#
# 	 unq images: 1513
#
# 	 path: ./data/datasets/forms/e07-101.png
#
# 	 unq images: 1514
#
# 	 path: ./data/datasets/forms/c03-021b.png
#
# 	 unq images: 1516
#
# 	 path: ./data/datasets/forms/m04-024.png
#
# 	 unq images: 1517
#
# 	 path: ./data/datasets/forms/d04-032.png
#
# 	 unq images: 1518
#
# 	 path: ./data/datasets/forms/m04-231.png
#
# 	 unq images: 1519
#
# 	 path: ./data/datasets/forms/p03-047.png
#
# 	 unq images: 1521
#
# 	 unq images: 1522
#
# 	 path: ./data/datasets/forms/b04-010.png
#
# 	 unq images: 1523
#
# 	 path: ./data/datasets/forms/m02-087.png
#
# 	 unq images: 1524
#
# 	 path: ./data/datasets/forms/a01-117.png
#
# 	 unq images: 1526
#
# 	 path: ./data/datasets/forms/b04-054.png
#
# 	 unq images: 1527
#
# 	 path: ./data/datasets/forms/g06-018c.png
#
# 	 unq images: 1528
#
# 	 path: ./data/datasets/forms/n02-151.png
#
# 	 unq images: 1530
#
# 	 unq images: 1531
#
# 	 path: ./data/datasets/forms/r02-078.png
#
# 	 unq images: 1533
#
# 	 path: ./data/datasets/forms/a04-000.png
#
# 	 unq images: 1534
#
# 	 path: ./data/datasets/forms/g06-047h.png
#
# 	 unq images: 1536
#
# 	 path: ./data/datasets/forms/c03-000c.png
#
# 	 unq images: 1537
#
# 	 path: ./data/datasets/forms/b05-045.png
#
# 	 unq images: 1538
#  trainValCount: 71807  testCount: 17996

# %%
"""
    image visualization
"""

def drawRect(img,l):
    
    image=cv2.rectangle(img, (l[0], l[1]), (l[2], l[3]),(0,0,0),5)
    
    return image

# %%
#for file in ['train','test']:
import numpy as np
import os

allImagesPath="/home/aniketag/Documents/phd/yolov5/data/datasets/forms//"
allImages=os.listdir(allImagesPath)
images_num=len(allImages)#len(os.listdir("/home/k/phd/yolov5/data/datasets/forms/"))
images_path = allImagesPath # "/home/k/phd/yolov5/data/datasets/forms/"#os.getcwd()+f"/mnist_{file}"

#labels_txt = os.getcwd()+"/"+"mnist_train1.txt"

labels_txt =os.path.join(os.getcwd(),"mnist","delMe_mnist_train_PhoscIamOfficialSplitForYoloAllLineLevel1.txt")
labels_txt2 =os.path.join(os.getcwd(),"mnist","delMe_mnist_test_PhoscIamOfficialSplitForYoloAllLineLevel1.txt")

trainValCount,testCount=0,0

lastName=""
curLine=""
prevLine=""
unqImg=[]
exceptionCount=0

for indx,info in df.iterrows():
        
    imgName=info.image_name
    lineName=info.cropName[:-3]+"\n"
    
    if indx==0:
        image_path =os.path.join(allImagesPath,info["image_name"])
        img=cv2.imread(image_path)
        print(" 1st image:",img.shape)
    
    try:
        if indx%100==0:
            print("\n\t unq images:",len(unqImg))

        if (imgName in trainList or imgName in validList):
            trainValCount+=1
            with open(labels_txt, "a") as wf:
                image_path =images_path+info["image_name"]

                if indx%100==0:
                    print("\n\t path:",image_path)

                if info["image_name"]!=lastName and info["image_name"] not in unqImg:
                    curLine=image_path

                    if len(prevLine):
                        #print("\n\t prevLine:",prevLine)
                        #wf.write( image_path+ "\n")
                        #wf.write(prevLine+"\n")
                        
                        
                        cv2.imwrite("/home/aniketag/Documents/phd/TensorFlow-2.x-YOLOv3/delme/annotationVisualize//"+lastName,img)

                        #cv2.imwrite(os.path.join(visFolder,lastName),img)
                        img=None
                        imgPath=os.path.join(allImagesPath,imgName)
                        img=cv2.imread(imgPath)
                        print("new imgName:",imgName," shape:",img.shape)                    

                        #input("1.check")


                else:
                    xmin,ymin=str(int(info["org_x1"])),str(int(info["org_y1"]))
                    xmax,ymax=str(int(info["org_x2"])),str(int(info["org_y2"]))
                    curLine += ' ' + ','.join([xmin, ymin, xmax, ymax, str(0)])
                    prevLine=curLine
                    
                    
                    try:
                        img=drawRect(img,[int(xmin),int(ymin),int(xmax),int(ymax)])
                        cv2.imwrite("/home/aniketag/Documents/phd/TensorFlow-2.x-YOLOv3/delme/annotationVisualize//"+imgName,img)
                        input("2.check")

                    except Exception as e:
                        pass

                lastName=info["image_name"]

            
        if info["image_name"] not in unqImg:
            unqImg.append(info["image_name"])

    except Exception as e:
        exceptionCount+=1
        print("\n\t exception index:",indx,"\t count:",exceptionCount)

        
print(" trainValCount:",trainValCount," testCount:",testCount)
# Out:
#  1st image: (3542, 2479, 3)
#
# 	 unq images: 0
#
# 	 unq images: 2
#
# 	 unq images: 3
# 2.check1
# 2.check1
# 2.check1
# 2.check1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [23], in <cell line: 23>()
#      73     img=drawRect(img,[int(xmin),int(ymin),int(xmax),int(ymax)])
#      74     cv2.imwrite("/home/aniketag/Documents/phd/TensorFlow-2.x-YOLOv3/delme/annotationVisualize//"+imgName,img)
# ---> 75     input("2.check")
#      77 except Exception as e:
#      78     pass
#
# File ~/.conda/envs/TensorFlow-2.x-YOLOv3/lib/python3.8/site-packages/ipykernel/kernelbase.py:1076, in Kernel.raw_input(self, prompt)
#    1072 if not self._allow_stdin:
#    1073     raise StdinNotImplementedError(
#    1074         "raw_input was called, but this frontend does not support input requests."
#    1075     )
# -> 1076 return self._input_request(
#    1077     str(prompt),
#    1078     self._parent_ident["shell"],
#    1079     self.get_parent("shell"),
#    1080     password=False,
#    1081 )
#
# File ~/.conda/envs/TensorFlow-2.x-YOLOv3/lib/python3.8/site-packages/ipykernel/kernelbase.py:1121, in Kernel._input_request(self, prompt, ident, parent, password)
#    1118             break
#    1119 except KeyboardInterrupt:
#    1120     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1121     raise KeyboardInterrupt("Interrupted by user") from None
#    1122 except Exception:
#    1123     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# """
#     neglect below part
#
# """

# %%
def drawRect(img,l):
    
    image=cv2.rectangle(img, (l[0], l[1]), (l[2], l[3]),(0,0,0),5)
    
    return image

# %% [markdown]
# """
#     below part creates a necessary files
# """

# %%
# for file in ['train','test']:
import numpy as np
import os
import cv2
import sys

#allImagesPath="/home/aniketag/Documents/phd/yolov5/data/datasets/forms//"
allImagesPath="/home/aniketag/Documents/phd/yolov5/data/datasets/forms//"
allImages=os.listdir(allImagesPath)
images_num=len(allImages)#len(os.listdir("/home/k/phd/yolov5/data/datasets/forms/"))
images_path = allImagesPath # "/home/k/phd/yolov5/data/datasets/forms/"#os.getcwd()+f"/mnist_{file}"
visFolder=os.path.join(os.getcwd(),"delMe","annotationVisualize")


#labels_txt = os.getcwd()+"/"+"mnist_train1.txt"

labels_txt =os.path.join(os.getcwd(),"mnist","mnist_train_PhoscIamOfficialSplitForYoloAllLineLevel1.txt")
labels_txt2 =os.path.join(os.getcwd(),"mnist","mnist_test_PhoscIamOfficialSplitForYoloAllLineLevel1.txt")


#labels_txt = os.getcwd()+"/"+"mnist_train_PhoscIamOfficialSplitForYolo.txt"
#labels_txt2 = os.getcwd()+"/"+"mnist_test_PhoscIamOfficialSplitForYolo.txt"

lastName=""
curLine=""
prevLine=""
unqImg=[]
exceptionCount=0
notFound=0

for indx,info in df.iterrows():
    
    imgName=info.image_name
    lineName=info.cropName[:-3]+"\n"
    #print(" lineName=",lineName)

    if indx==0:
        image_path =os.path.join(allImagesPath,info["image_name"])
        img=cv2.imread(image_path)
        print(" 1st image:",img.shape)
        
    if indx==2000:
        break
    
    try:
        if indx%100==0:
            print("\n\t unq images:",len(unqImg)," indx:",indx)

        #if (imgName in trainList and lineName in trainLines) or (imgName in validList and lineName in valLines):# or imgName in validList:

        if 1:
   
            if indx%100==0:
                print("\n\t path:",image_path)
                    
            
            if info["image_name"]!=lastName and info["image_name"] not in unqImg:
                curLine=image_path


                cv2.imwrite("/home/aniketag/Documents/phd/TensorFlow-2.x-YOLOv3/delme/annotationVisualize//"+lastName,img)

                #cv2.imwrite(os.path.join(visFolder,lastName),img)
                img=None
                imgPath=os.path.join(allImagesPath,imgName)
                img=cv2.imread(imgPath)
                print("new imgName:",imgName," shape:",img.shape)                    

                #input("1.check")

                    
                else:
                    
                    """
                        no need to write in file now just keep adding in line
                    """
                    
                    xmin,ymin=str(int(info["org_x1"])),str(int(info["org_y1"]))
                    xmax,ymax=str(int(info["org_x2"])),str(int(info["org_y2"]))
                    curLine += ' ' + ','.join([xmin, ymin, xmax, ymax, str(0)])
                    prevLine=curLine
                                        
                    try:
                        img=drawRect(img,[int(xmin),int(ymin),int(xmax),int(ymax)])
                        cv2.imwrite("/home/aniketag/Documents/phd/TensorFlow-2.x-YOLOv3/delme/annotationVisualize//"+imgName,img)
                        input("1.check")

                    except Exception as e:
                        pass


                lastName=info["image_name"]

        #elif imgName in testList and lineName in testLines:
        elif imgName in testList:

                image_path =os.path.join("./data/datasets/forms/",info["image_name"])

                if indx%100==0:
                    print("\n\t path:",image_path)

                if info["image_name"]!=lastName:
                    curLine=image_path

                    if len(prevLine):
                        #print("\n\t prevLine:",prevLine)
                        #wf.write( image_path+ "\n")
                        #cv2.imwrite(os.path.join(visFolder,lastName),img)

                        cv2.imwrite("/home/aniketag/Documents/phd/TensorFlow-2.x-YOLOv3/delme/annotationVisualize//"+lastName,img)
                        imgPath=os.path.join(allImagesPath,imgName)
                        img=None
                        img=cv2.imread(imgPath)
                        #input("2.check")

                else:
                    xmin,ymin=str(int(info["org_x1"])),str(int(info["org_y1"]))
                    xmax,ymax=str(int(info["org_x2"])),str(int(info["org_y2"]))
                    curLine += ' ' + ','.join([xmin, ymin, xmax, ymax, str(0)])
                    prevLine=curLine

                    try:
                        img=drawRect(img,[int(xmin),int(ymin),int(xmax),int(ymax)])
                        cv2.imwrite("/home/aniketag/Documents/phd/TensorFlow-2.x-YOLOv3/delme/annotationVisualize//"+imgName,img)
                        input("2.check")

                    except Exception as e:
                        pass                    
                    
                lastName=info["image_name"]
        else:
            notFound+=1
            #break        
        
        if info["image_name"] not in unqImg:
            unqImg.append(info["image_name"])

    except Exception as e:
        exceptionCount+=1
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        #print(exc_type, fname, exc_tb.tb_lineno)
        
        print("\n\t exception index:",indx,"\t count:",exceptionCount," e:",e," line no:",exc_tb.tb_lineno)
    
        
print(" notFound:",notFound)
# Out:
#  1st image: (3542, 2479, 3)
#
# 	 unq images: 0  indx: 0
#
# 	 unq images: 2  indx: 100
# 2.check1
# 2.check1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <cell line: 31>()
#     126     img=drawRect(img,[int(xmin),int(ymin),int(xmax),int(ymax)])
#     127     cv2.imwrite("/home/aniketag/Documents/phd/TensorFlow-2.x-YOLOv3/delme/annotationVisualize//"+imgName,img)
# --> 128     input("2.check")
#     130 except Exception as e:
#     131     pass
#
# File ~/.conda/envs/TensorFlow-2.x-YOLOv3/lib/python3.8/site-packages/ipykernel/kernelbase.py:1076, in Kernel.raw_input(self, prompt)
#    1072 if not self._allow_stdin:
#    1073     raise StdinNotImplementedError(
#    1074         "raw_input was called, but this frontend does not support input requests."
#    1075     )
# -> 1076 return self._input_request(
#    1077     str(prompt),
#    1078     self._parent_ident["shell"],
#    1079     self.get_parent("shell"),
#    1080     password=False,
#    1081 )
#
# File ~/.conda/envs/TensorFlow-2.x-YOLOv3/lib/python3.8/site-packages/ipykernel/kernelbase.py:1121, in Kernel._input_request(self, prompt, ident, parent, password)
#    1118             break
#    1119 except KeyboardInterrupt:
#    1120     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1121     raise KeyboardInterrupt("Interrupted by user") from None
#    1122 except Exception:
#    1123     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# for file in ['train','test']:
import numpy as np
import os
import cv2
#allImagesPath="/home/aniketag/Documents/phd/yolov5/data/datasets/forms//"
allImagesPath="/home/aniketag/Documents/phd/yolov5/data/datasets/forms//"
allImages=os.listdir(allImagesPath)
images_num=len(allImages)#len(os.listdir("/home/k/phd/yolov5/data/datasets/forms/"))
images_path = allImagesPath # "/home/k/phd/yolov5/data/datasets/forms/"#os.getcwd()+f"/mnist_{file}"
visFolder=os.path.join(os.getcwd(),"delMe","annotationVisualize")


#labels_txt = os.getcwd()+"/"+"mnist_train1.txt"

labels_txt =os.path.join(os.getcwd(),"mnist","mnist_train_PhoscIamOfficialSplitForYoloAllLineLevel1.txt")
labels_txt2 =os.path.join(os.getcwd(),"mnist","mnist_test_PhoscIamOfficialSplitForYoloAllLineLevel1.txt")


#labels_txt = os.getcwd()+"/"+"mnist_train_PhoscIamOfficialSplitForYolo.txt"
#labels_txt2 = os.getcwd()+"/"+"mnist_test_PhoscIamOfficialSplitForYolo.txt"

lastName=""
curLine=""
prevLine=""
unqImg=[]
exceptionCount=0
notFound=0

for indx,info in df.iterrows():
    
    imgName=info.image_name
    lineName=info.cropName[:-3]+"\n"
    #print(" lineName=",lineName)
    
    if indx==0:
        image_path =os.path.join(allImagesPath,info["image_name"])
        img=cv2.imread(image_path)
        print(" 1st image:",img.shape)
    
    if indx==2000:
        break
    
    try:
        if indx%100==0:
            print("\n\t unq images:",len(unqImg))

        #if (imgName in trainList and lineName in trainLines) or (imgName in validList and lineName in valLines):# or imgName in validList:

        if (imgName in trainList or imgName in validList): # or imgName in validList:
   
            if indx%100==0:
                print("\n\t path:",image_path)
            
            
            with open(labels_txt, "a") as wf:
                image_path =os.path.join("./data/datasets/forms/",info["image_name"])

                """
                    below condition indicates different image present on current and previous
                    line of dataframe, So need to write content for prev line
                """                
                
                if info["image_name"]!=lastName and info["image_name"] not in unqImg:
                    curLine=image_path

                    if len(prevLine):
                        #print("\n\t prevLine:",prevLine)
                        #wf.write( image_path+ "\n")
                        wf.write(prevLine+"\n")
                    
                        cv2.imwrite("/home/aniketag/Documents/phd/TensorFlow-2.x-YOLOv3/delme/annotationVisualize//"+lastName,img)
                        
                        #cv2.imwrite(os.path.join(visFolder,lastName),img)
                        img=None
                        imgPath=os.path.join(allImagesPath,imgName)
                        img=cv2.imread(imgPath)
                        print("new imgName:",imgName," shape:",img.shape)                    
                    
                        #input("1.check")

                    
                else:
                    
                    """
                        no need to write in file now just keep adding in line
                    """
                    
                    xmin,ymin=str(int(info["org_x1"])),str(int(info["org_y1"]))
                    xmax,ymax=str(int(info["org_x2"])),str(int(info["org_y2"]))
                    curLine += ' ' + ','.join([xmin, ymin, xmax, ymax, str(0)])
                    prevLine=curLine
                                        
                    try:
                        img=drawRect(img,[int(xmin),int(ymin),int(xmax),int(ymax)])
                        cv2.imwrite("/home/aniketag/Documents/phd/TensorFlow-2.x-YOLOv3/delme/annotationVisualize//"+imgName,img)
                        input("1.check")

                    except Exception as e:
                        pass


                lastName=info["image_name"]

        #elif imgName in testList and lineName in testLines:
        elif imgName in testList:

            with open(labels_txt2, "a") as wf:
                image_path =os.path.join("./data/datasets/forms/",info["image_name"])

                if indx%100==0:
                    print("\n\t path:",image_path)

                if info["image_name"]!=lastName:
                    curLine=image_path

                    if len(prevLine):
                        #print("\n\t prevLine:",prevLine)
                        #wf.write( image_path+ "\n")
                        wf.write(prevLine+"\n")
                        #cv2.imwrite(os.path.join(visFolder,lastName),img)

                        cv2.imwrite("/home/aniketag/Documents/phd/TensorFlow-2.x-YOLOv3/delme/annotationVisualize//"+lastName,img)
                        imgPath=os.path.join(allImagesPath,imgName)
                        img=None
                        img=cv2.imread(imgPath)
                        #input("2.check")

                else:
                    xmin,ymin=str(int(info["org_x1"])),str(int(info["org_y1"]))
                    xmax,ymax=str(int(info["org_x2"])),str(int(info["org_y2"]))
                    curLine += ' ' + ','.join([xmin, ymin, xmax, ymax, str(0)])
                    prevLine=curLine

                    try:
                        img=drawRect(img,[int(xmin),int(ymin),int(xmax),int(ymax)])
                        cv2.imwrite("/home/aniketag/Documents/phd/TensorFlow-2.x-YOLOv3/delme/annotationVisualize//"+imgName,img)
                        input("2.check")

                    except Exception as e:
                        pass                    
                    
                lastName=info["image_name"]
        else:
            notFound+=1
            #break        
        
        if info["image_name"] not in unqImg:
            unqImg.append(info["image_name"])

    except Exception as e:
        exceptionCount+=1
        print("\n\t exception index:",indx,"\t count:",exceptionCount)
    
        
print(" notFound:",notFound)

# %%
"a03-047-05\n" in trainLines
